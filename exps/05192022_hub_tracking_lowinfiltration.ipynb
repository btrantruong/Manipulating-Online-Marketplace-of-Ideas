# %%
import json
import infosys.utils as utils 
import igraph as ig
import os
import collections
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl
import seaborn as sns

# %%
ABS_PATH = '/N/slate/baotruon/marketplace'
DATA_PATH = '/N/slate/baotruon/marketplace/data'

print(os.getcwd())
exp_configs = json.load(open(os.path.join(DATA_PATH, 'all_configs.json'),'r'))
EXPS = list(exp_configs['vary_thetaphi'].keys()) #keys are name of exp, format: '{targeting}_{thetaidx}{phiidx}' 

# map available network in `vary_targetgamma` corresponding with the exp
# networks from `vary_targetgamma` has format: '{targeting}{gamma}'
GAMMA = [0.0001, 0.0002, 0.0005, 0.001, 0.002, 0.005, 0.02, 0.05, 0.1, 0.2, 0.5]
TARGETING = [None, 'hubs', 'partisanship', 'conservative', 'liberal', 'misinformation']

EXP_NETWORK = {}

gamma = 0.005 # gamma in the range where targeting has some effect
# need to match with default_targeting
for exp in EXPS:
    if 'none' in exp:
        networkname = '%s%s' %(TARGETING.index(None), GAMMA.index(gamma))
    else: 
        networkname = '%s%s' %(TARGETING.index(exp.split('_')[0]), GAMMA.index(gamma) )
    EXP_NETWORK[exp] = networkname
# Out:
# /geode2/home/u010/baotruon/Carbonate/marketplace/exps

# %%
sim_num = 1
mode='igraph'
RES_DIR = os.path.join(ABS_PATH,'results', 'vary_thetaphi_1runs_gamma0.005')
TRACKING_DIR = os.path.join(ABS_PATH,'long_results', 'vary_thetaphi_1runs_gamma0.005')

# %%
exp_no = 'none_02'
fpath = os.path.join(TRACKING_DIR,'%s.json.gz' %exp_no)

# %%
EXP_NETWORK[exp_no]
# Out:
# '05'

# %%
network = os.path.join(DATA_PATH, mode, 'vary_targetgamma', "network_%s.gml" %EXP_NETWORK[exp_no])

# %%
G = ig.Graph.Read_GML(network)

# %%
len([n for n in G.vs if n['bot']==0])
# Out:
# 10006

# %%
len(G.vs)
# Out:
# 10106

# %%
verbose = utils.read_json_compressed(fpath)

# %%
#verbose['all_memes']

# %%
spreading = [node for meme in verbose['all_memes'] for node in meme['spread_via_agents']]

# %%
verbose['all_memes'][0]
# Out:
# [{'id': 1,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.4692894983895298,
#   'fitness': 0.4692894983895298,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [6418],
#   'qual_th': 76816,
#   'share_th': 64892},
#  {'id': 2,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1163730344695505,
#   'fitness': 0.1163730344695505,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8400],
#   'qual_th': 24162,
#   'share_th': 22141},
#  {'id': 3,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.18068785874372073,
#   'fitness': 0.18068785874372073,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1256],
#   'qual_th': 35576,
#   'share_th': 32143},
#  {'id': 4,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.14256396141231165,
#   'fitness': 0.14256396141231165,
#   'human_shares': 5,
#   'bot_shares': 0,
#   'spread_via_agents': [2158, 5507, 6349, 4127, 309],
#   'qual_th': 28998,
#   'share_th': 100904},
#  {'id': 5,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.2728762964072863,
#   'fitness': 0.2728762964072863,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [8025, 1277],
#   'qual_th': 50789,
#   'share_th': 88376},
#  {'id': 6,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7609735451570963,
#   'fitness': 0.7609735451570963,
#   'human_shares': 6,
#   'bot_shares': 0,
#   'spread_via_agents': [9903, 4001, 5510, 2503, 238, 7904],
#   'qual_th': 100499,
#   'share_th': 102784},
#  {'id': 7,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.10479739053074355,
#   'fitness': 0.10479739053074355,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4377],
#   'qual_th': 21981,
#   'share_th': 20176},
#  {'id': 8,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5131851025833944,
#   'fitness': 0.5131851025833944,
#   'human_shares': 9,
#   'bot_shares': 0,
#   'spread_via_agents': [6730, 87, 6940, 5882, 9271, 2915, 7047, 4629, 5561],
#   'qual_th': 81627,
#   'share_th': 104040},
#  {'id': 9,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.4474963874046768,
#   'fitness': 0.4474963874046768,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2388],
#   'qual_th': 74386,
#   'share_th': 63140},
#  {'id': 10,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5898969734825144,
#   'fitness': 0.5898969734825144,
#   'human_shares': 50,
#   'bot_shares': 0,
#   'spread_via_agents': [7649,
#    5916,
#    6753,
#    7216,
#    6785,
#    6809,
#    6328,
#    9711,
#    2104,
#    1153,
#    4491,
#    44,
#    5729,
#    7581,
#    2122,
#    3075,
#    9697,
#    7582,
#    5640,
#    9969,
#    1020,
#    8046,
#    2645,
#    3293,
#    6211,
#    2434,
#    1772,
#    9460,
#    7083,
#    6448,
#    8826,
#    717,
#    8232,
#    3530,
#    8184,
#    8747,
#    3964,
#    534,
#    8930,
#    3675,
#    5661,
#    9945,
#    4999,
#    5050,
#    3530,
#    3530,
#    7438,
#    2015,
#    2472,
#    2289],
#   'qual_th': 88801,
#   'share_th': 106263},
#  {'id': 11,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.08721090334314685,
#   'fitness': 0.08721090334314685,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4163],
#   'qual_th': 18617,
#   'share_th': 17104},
#  {'id': 12,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3134329915304558,
#   'fitness': 0.3134329915304558,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3486],
#   'qual_th': 56927,
#   'share_th': 49803},
#  {'id': 13,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7250973579566218,
#   'fitness': 0.7250973579566218,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [9962],
#   'qual_th': 98581,
#   'share_th': 79780},
#  {'id': 14,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.23548983117585687,
#   'fitness': 0.23548983117585687,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7571],
#   'qual_th': 44855,
#   'share_th': 39973},
#  {'id': 15,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5557371643970583,
#   'fitness': 0.5557371643970583,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2587],
#   'qual_th': 85700,
#   'share_th': 71186},
#  {'id': 16,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1013956010631365,
#   'fitness': 0.1013956010631365,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [6815],
#   'qual_th': 21318,
#   'share_th': 19580},
#  {'id': 17,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.2823823501270809,
#   'fitness': 0.2823823501270809,
#   'human_shares': 45,
#   'bot_shares': 0,
#   'spread_via_agents': [2583,
#    2172,
#    4911,
#    8551,
#    5072,
#    3475,
#    8124,
#    484,
#    2510,
#    5883,
#    1751,
#    9417,
#    7388,
#    7475,
#    960,
#    9578,
#    159,
#    4929,
#    4559,
#    1454,
#    4932,
#    4961,
#    5703,
#    5302,
#    798,
#    896,
#    8469,
#    4082,
#    6931,
#    971,
#    1777,
#    7572,
#    7010,
#    1862,
#    2010,
#    4602,
#    8475,
#    43,
#    4493,
#    4093,
#    6466,
#    4378,
#    2897,
#    8434,
#    2537],
#   'qual_th': 52306,
#   'share_th': 106216},
#  {'id': 18,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7245291203710639,
#   'fitness': 0.7245291203710639,
#   'human_shares': 3,
#   'bot_shares': 0,
#   'spread_via_agents': [4092, 7887, 7032],
#   'qual_th': 98555,
#   'share_th': 98474},
#  {'id': 19,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.

#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1977],
#   'qual_th': 10643,
#   'share_th': 9608},
#  {'id': 25,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5209180825467301,
#   'fitness': 0.5209180825467301,
#   'human_shares': 4,
#   'bot_shares': 0,
#   'spread_via_agents': [4834, 5321, 5071, 8057],
#   'qual_th': 82424,
#   'share_th': 100034},
#  {'id': 26,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1887876419982737,
#   'fitness': 0.1887876419982737,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2609],
#   'qual_th': 36980,
#   'share_th': 33348},
#  {'id': 27,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.10674960309373516,
#   'fitness': 0.10674960309373516,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [362],
#   'qual_th': 22320,
#   'share_th': 20484},
#  {'id': 28,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3334482952105783,
#   'fitness': 0.3334482952105783,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2959],
#   'qual_th': 59762,
#   'share_th': 52025},
#  {'id': 29,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3690804658452165,
#   'fitness': 0.3690804658452165,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1277],
#   'qual_th': 64683,
#   'share_th': 55862},
#  {'id': 30,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5779376691643916,
#   'fitness': 0.5779376691643916,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4604],
#   'qual_th': 87781,
#   'share_th': 72616},
#  {'id': 31,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3681565266350738,
#   'fitness': 0.3681565266350738,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [936],
#   'qual_th': 64552,
#   'share_th': 55760},
#  {'id': 32,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.8456842671548653,
#   'fitness': 0.8456842671548653,
#   'human_shares': 4,
#   'bot_shares': 0,
#   'spread_via_agents': [9929, 2519, 9751, 5372],
#   'qual_th': 103995,
#   'share_th': 100742},
#  {'id': 33,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.37926875463319754,
#   'fitness': 0.37926875463319754,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [8105, 2830],
#   'qual_th': 66018,
#   'share_th': 90150},
#  {'id': 34,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.15673978467816352,
#   'fitness': 0.15673978467816352,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8872],
#   'qual_th': 31484,
#   'share_th': 28597},
#  {'id': 35,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.003730600751251756,
#   'fitness': 0.003730600751251756,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [6329],
#   'qual_th': 1873,
#   'share_th': 1052},
#  {'id': 36,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.12677212881489652,
#   'fitness': 0.12677212881489652,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8117],
#   'qual_th': 26082,
#   'share_th': 23880},
#  {'id': 37,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.21008790398814114,
#   'fitness': 0.21008790398814114,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5304],
#   'qual_th': 40597,
#   'share_th': 36450},
#  {'id': 38,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3176129550862097,
#   'fitness': 0.3176129550862097,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2121],
#   'qual_th': 57560,
#   'share_th': 50301},
#  {'id': 39,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.03536059955279791,
#   'fitness': 0.03536059955279791,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [5940, 8803],
#   'qual_th': 8419,
#   'share_th': 84917},
#  {'id': 40,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7988208543827426,
#   'fitness': 0.7988208543827426,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2340],
#   'qual_th': 102247,
#   'share_th': 82103},
#  {'id': 41,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5967057031867761,
#   'fitness': 0.5967057031867761,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4133],
#   'qual_th': 89377,
#   'share_th': 73701},
#  {'id': 42,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5317066501861135,
#   'fitness': 0.5317066501861135,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [710],
#   'qual_th': 83445,
#   'share_th': 69624},
#  {'id': 43,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6799859203049193,
#   'fitness': 0.6799859203049193,
#   'human_shares': 12,
#   'bot_shares': 0,
#   'spread_via_agents': [2987,
#    7660,
#    6732,
#    3836,
#    2533,
#    2316,
#    6008,
#    127,
#    7557,
#    6333,
#    3467,
#    714],
#   'qual_th': 95775,
#   'share_th': 104836},
#  {'id': 44,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.2917612361941574,
#   'fitness': 0.2917612361941574,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [3223, 6152],
#   'qual_th': 53707,
#   'share_th': 88713},
#  {'id': 45,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6536679431656385,
#   'fitness': 0.6536679431656385,
#   'human_shares': 25,
#   'bot_shares': 0,
#   'spread_via_agents': [1509,
#    5157,
#    3738,
#    4491,
#    247,
#    6255,
#    5946,
#    8513,
#    634,
#    4183,
#    6443,
#    7620,
#    5844,
#    947,
#    8341,
#    6481,
#    1236,
#    9584,
#    7449,
#    2711,
#    1943,
#    930,
#    9105,
#    7314,
#    724],
#   'qual_th': 93964,
#   'share_th': 105898},
#  {'id': 46,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7162538463159198,
#   'fitness': 0.7162538463159198,
#   'human_shares': 9,
#   'bot_shares': 0,
#   'spread_via_agents': [5371, 4569, 5755, 2696, 1042, 4684, 8708, 6556, 6127],
#   'qual_th': 98062,
#   'share_th': 104169},
#  {'id': 47,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.4007075918382801,
#   'fitness': 0.4007075918382801,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1732],
#   'qual_th': 68719,
#   'share_th': 58934},
#  {'id': 48,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.15198829994361795,
#   'fitness': 0.15198829994361795,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [5959, 6420],
#   'qual_th': 30636,
#   'share_th': 86375},
#  {'id': 49,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.13801028874468613,
#   'fitness': 0.13801028874468613,
#   'human_shares': 9,
#   'bot_shares': 0,
#   'spread_via_agents': [2123, 1794, 7795, 0, 6448, 5219, 1319, 1857, 5091],
#   'qual_th': 28152,
#   'share_th': 103926},
#  {'id': 50,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.22616526962534145,
#   'fitness': 0.22616526962534145,
#   'human_shares': 5,
#   'bot_shares': 0,
#   'spread_via_agents': [8154, 6169, 2170, 4295, 7163],
#   'qual_th': 43319,
#   'share_th': 100978},
#  {'id': 51,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7119594288544582,
#   'fitness': 0.7119594288544582,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5332],
#   'qual_th': 97816,
#   'share_th': 79286},
#  {'id': 52,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.2480510530905754,
#   'fitness': 0.2480510530905754,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [643],
#   'qual_th': 46898,
#   'share_th': 41684},
#  {'id': 53,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.12204321461721002,
#   'fitness': 0.12204321461721002,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2931],
#   'qual_th': 25211,
#   'share_th': 23091},
#  {'id': 54,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3476156372220387,
#   'fitness': 0.3476156372220387,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4922],
#   'qual_th': 61660,
#   'share_th': 53521},
#  {'id': 55,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.08479918924325458,
#   'fitness': 0.08479918924325458,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5560],
#   'qual_th': 18139,
#   'share_th': 16660},
#  {'id': 56,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3038361280165959,
#   'fitness': 0.3038361280165959,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [9832],
#   'qual_th': 55513,
#   'share_th': 48687},
#  {'id': 57,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6104475480688739,
#   'fitness': 0.6104475480688739,
#   'human_shares': 5,
#   'bot_shares': 0,
#   'spread_via_agents': [6172, 178, 3962, 9144, 5019],
#   'qual_th': 90589,
#   'share_th': 101707},
#  {'id': 58,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.03209901196283793,
#   'fitness': 0.03209901196283793,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3761],
#   'qual_th': 7771,
#   'share_th': 6847},
#  {'id': 59,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.45260961502105945,
#   'fitness': 0.45260961502105945,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [9626],
#   'qual_th': 74970,
#   'share_th': 63557},
#  {'id': 60,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.06858062767358586,
#   'fitness': 0.06858062767358586,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [7915, 2200],
#   'qual_th': 15013,
#   'share_th': 85195},
#  {'id': 61,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.15541628319342027,
#   'fitness': 0.15541628319342027,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3661],
#   'qual_th': 31249,
#   'share_th': 28401},
#  {'id': 62,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.34808875641986525,
#   'fitness': 0.34808875641986525,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [6702],
#   'qual_th': 61733,
#   'share_th': 53571},
#  {'id': 63,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0

#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.33878340488514314,
#   'fitness': 0.33878340488514314,
#   'human_shares': 6,
#   'bot_shares': 0,
#   'spread_via_agents': [6108, 7631, 2175, 2971, 9403, 8546],
#   'qual_th': 60487,
#   'share_th': 102238},
#  {'id': 70,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7256871616516816,
#   'fitness': 0.7256871616516816,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8887],
#   'qual_th': 98616,
#   'share_th': 79806},
#  {'id': 71,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.10932321172045967,
#   'fitness': 0.10932321172045967,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [7880, 8985],
#   'qual_th': 22813,
#   'share_th': 85705},
#  {'id': 72,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.13976162430792383,
#   'fitness': 0.13976162430792383,
#   'human_shares': 4,
#   'bot_shares': 0,
#   'spread_via_agents': [4327, 5985, 4242, 9631],
#   'qual_th': 28473,
#   'share_th': 99031},
#  {'id': 73,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.07101472808663811,
#   'fitness': 0.07101472808663811,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7566],
#   'qual_th': 15490,
#   'share_th': 14190},
#  {'id': 74,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.32384960856857714,
#   'fitness': 0.32384960856857714,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7400],
#   'qual_th': 58443,
#   'share_th': 50987},
#  {'id': 75,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.09898225944540229,
#   'fitness': 0.09898225944540229,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1643],
#   'qual_th': 20861,
#   'share_th': 19167},
#  {'id': 76,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3481408088249054,
#   'fitness': 0.3481408088249054,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7166],
#   'qual_th': 61741,
#   'share_th': 53578},
#  {'id': 77,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6880458466197802,
#   'fitness': 0.6880458466197802,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3365],
#   'qual_th': 96301,
#   'share_th': 78308},
#  {'id': 78,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.17165748763030508,
#   'fitness': 0.17165748763030508,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [6914],
#   'qual_th': 34049,
#   'share_th': 30835},
#  {'id': 79,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.03120513780115708,
#   'fitness': 0.03120513780115708,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [559],
#   'qual_th': 7588,
#   'share_th': 6670},
#  {'id': 80,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.07631950315965375,
#   'fitness': 0.07631950315965375,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7235],
#   'qual_th': 16516,
#   'share_th': 15164},
#  {'id': 81,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.013479356568753764,
#   'fitness': 0.013479356568753764,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [6029],
#   'qual_th': 3896,
#   'share_th': 3061},
#  {'id': 82,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3502399033237724,
#   'fitness': 0.3502399033237724,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5682],
#   'qual_th': 62015,
#   'share_th': 53799},
#  {'id': 83,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1752100762358021,
#   'fitness': 0.1752100762358021,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [791],
#   'qual_th': 34660,
#   'share_th': 31359},
#  {'id': 84,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3702826451794625,
#   'fitness': 0.3702826451794625,
#   'human_shares': 5,
#   'bot_shares': 0,
#   'spread_via_agents': [9198, 6163, 4176, 707, 9119],
#   'qual_th': 64843,
#   'share_th': 101214},
#  {'id': 85,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5334853690657964,
#   'fitness': 0.5334853690657964,
#   'human_shares': 7,
#   'bot_shares': 0,
#   'spread_via_agents': [9585, 315, 4011, 1179, 9780, 595, 4700],
#   'qual_th': 83615,
#   'share_th': 103201},
#  {'id': 86,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.055691077675815714,
#   'fitness': 0.055691077675815714,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [7337, 6724],
#   'qual_th': 12514,
#   'share_th': 85073},
#  {'id': 87,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.37759868474699665,
#   'fitness': 0.37759868474699665,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [112],
#   'qual_th': 65806,
#   'share_th': 56712},
#  {'id': 88,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.15938155135362164,
#   'fitness': 0.15938155135362164,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [2055, 1021],
#   'qual_th': 31915,
#   'share_th': 86500},
#  {'id': 89,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.2723216666781151,
#   'fitness': 0.2723216666781151,
#   'human_shares': 9,
#   'bot_shares': 0,
#   'spread_via_agents': [3373, 5508, 5629, 1098, 882, 1021, 7723, 4716, 4716],
#   'qual_th': 50709,
#   'share_th': 103942},
#  {'id': 90,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5031946380612446,
#   'fitness': 0.5031946380612446,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [7566, 4530],
#   'qual_th': 80581,
#   'share_th': 91935},
#  {'id': 91,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.8017215329488996,
#   'fitness': 0.8017215329488996,
#   'human_shares': 10,
#   'bot_shares': 0,
#   'spread_via_agents': [7998,
#    6488,
#    900,
#    998,
#    1012,
#    3827,
#    475,
#    2872,
#    5612,
#    1698],
#   'qual_th': 102378,
#   'share_th': 104474},
#  {'id': 92,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.2677923232491175,
#   'fitness': 0.2677923232491175,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [828],
#   'qual_th': 50029,
#   'share_th': 44291},
#  {'id': 93,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.45586350518745444,
#   'fitness': 0.45586350518745444,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2371],
#   'qual_th': 75319,
#   'share_th': 63812},
#  {'id': 94,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.14759003650043745,
#   'fitness': 0.14759003650043745,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8480],
#   'qual_th': 29870,
#   'share_th': 27206},
#  {'id': 95,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.11989372982910895,
#   'fitness': 0.11989372982910895,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1270],
#   'qual_th': 24817,
#   'share_th': 22733},
#  {'id': 96,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5259567962942804,
#   'fitness': 0.5259567962942804,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [3572, 9292],
#   'qual_th': 82901,
#   'share_th': 92235},
#  {'id': 97,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.13314489990509615,
#   'fitness': 0.13314489990509615,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1973],
#   'qual_th': 27290,
#   'share_th': 24936},
#  {'id': 98,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.37576123811427964,
#   'fitness': 0.37576123811427964,
#   'human_shares': 6,
#   'bot_shares': 0,
#   'spread_via_agents': [2067, 1985, 4781, 6394, 3946, 7990],
#   'qual_th': 65576,
#   'share_th': 102276},
#  {'id': 99,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.18767545287202936,
#   'fitness': 0.18767545287202936,
#   'human_shares': 5,
#   'bot_shares': 0,
#   'spread_via_agents': [857, 9842, 5037, 3380, 5045],
#   'qual_th': 36784,
#   'share_th': 100936},
#  {'id': 100,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3040653601254639,
#   'fitness': 0.3040653601254639,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3189],
#   'qual_th': 55541,
#   'share_th': 48708},
#  {'id': 101,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6343065902682619,
#   'fitness': 0.6343065902682619,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5850],
#   'qual_th': 92493,
#   'share_th': 75787},
#  {'id': 102,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.04667659564671722,
#   'fitness': 0.04667659564671722,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1914],
#   'qual_th': 10671,
#   'share_th': 9634},
#  {'id': 103,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7528616212718819,
#   'fitness': 0.7528616212718819,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [434, 2228],
#   'qual_th': 100095,
#   'share_th': 94442},
#  {'id': 104,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1576195273343467,
#   'fitness': 0.1576195273343467,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [9717],
#   'qual_th': 31633,
#   'share_th': 28728},
#  {'id': 105,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3876042132037806,
#   'fitness': 0.3876042132037806,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3486],
#   'qual_th': 67114,
#   'share_th': 57721},
#  {'id': 106,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.2136423128734829,
#   'fitness': 0.2136423128734829,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5661],
#   'qual_th': 41187,
#   'share_th': 36950},
#  {'id': 107,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.014128179582464373,
#   'fitness': 0.014128179582464373,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [6580, 5609],
#   'qual_th': 4034,
#   'share_th': 84817},
#  {'id': 108,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.004852335723640522,
#   'fitness': 0.004852335723640522,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5023],
#   'qual_th': 2123,
#   'share_th': 1301},
#  {'id': 109,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.22111867594021783,
#   'fitness': 0.22111867594021783,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3799],
#   'qual_th': 42426,
#   'share_th': 37988},
#  {'id': 110,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.10845442425175378,
#   'fitness': 0.10845442425175378,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2526],
#   'qual_th': 22645,
#   'share_th': 20782},
#  {'id': 111,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6256544650527064,
#   'fitness': 0.6256544650527064,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [446],
#   'qual_th': 91836,
#   'share_th': 75342},
#  {'id': 112,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.013550107282074841,
#   'fitness': 0.013550107282074841,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [923, 3014],
#   'qual_th': 3911,
#   'share_th': 84814},
#  {'id': 113,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7040933568985513,
#   'fitness': 0.7040933568985513,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [9207],
#   'qual_th': 97346,
#   'share_th': 78983},
#  {'id': 114,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.41777730963408,
#   'fitness': 0.41777730963408,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7430],
#   'qual_th': 70806,
#   'share_th': 60495},
#  {'id': 115,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.42342574757480256,
#   'fitness': 0.42342574757480256,
#   'human_shares': 3,
#   'bot_shares': 0,
#   'spread_via_agents': [671, 9482, 1499],
#   'qual_th': 71499,
#   'share_th': 97019},
#  {'id': 116,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.038883055239786635,
#   'fitness': 0.038883055239786635,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8650],
#   'qual_th': 9096,
#   'share_th': 8123},
#  {'id': 117,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7016363070388751,
#   'fitness': 0.7016363070388751,
#   'human_shares': 9,
#   'bot_shares': 0,
#   'spread_via_agents': [3023, 4820, 1298, 4355, 2974, 7399, 9110, 8126, 3106],
#   'qual_th': 97200,
#   'share_th': 104159},
#  {'id': 118,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.515266617021567,
#   'fitness': 0.515266617021567,
#   'human_shares': 4,
#   'bot_shares': 0,
#   'spread_via_agents': [6499, 8968, 9053, 8168],
#   'qual_th': 81825,
#   'share_th': 100013},
#  {'id': 119,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.415740884772949,
#   'fitness': 0.415740884772949,
#   'human_shares': 3,
#   'bot_shares': 0,
#   'spread_via_agents': [3081, 3053, 3190],
#   'qual_th': 70571,
#   'share_th': 96975},
#  {'id': 120,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.4646799651774618,
#   'fitness': 0.4646799651774618,
#   'human_shares': 14,
#   'bot_shares': 0,
#   'spread_via_agents': [5124,
#    1277,
#    7847,
#    8379,
#    8424,
#    9253,
#    5585,
#    6634,
#    299,
#    8819,
#    6236,
#    7647,
#    3917,
#    8543],
#   'qual_th': 76301,
#   'share_th': 105096},
#  {'id': 121,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.375021800998497,
#   'fitness': 0.375021800998497,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [66, 6143],
#   'qual_th': 65470,
#   'share_th': 90084},
#  {'id': 122,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.07911012945661444,
#   'fitness': 0.07911012945661444,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1206],
#   'qual_th': 17055,
#   'share_th': 15656},
#  {'id': 123,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.11474306758558783,
#   'fitness': 0.11474306758558783,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [957, 8946],
#   'qual_th': 23843,
#   'share_th': 85789},
#  {'id': 124,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.13768157256886426,
#   'fitness': 0.13768157256886426,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [9491],
#   'qual_th': 28099,
#   'share_th': 25649},
#  {'id': 125,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.659713890858418,
#   'fitness': 0.659713890858418,
#   'human_shares': 3,
#   'bot_shares': 0,
#   'spread_via_agents': [8693, 3918, 3750],
#   'qual_th': 94429,
#   'share_th': 98220},
#  {'id': 126,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1724597860082291,
#   'fitness': 0.1724597860082291,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8164],
#   'qual_th': 34200,
#   'share_th': 30968},
#  {'id': 127,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.04028806031695853,
#   'fitness': 0.04028806031695853,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8622],
#   'qual_th': 9346,
#   'share_th': 8361},
#  {'id': 128,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.18633342644884088,
#   'fitness': 0.18633342644884088,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [6088],
#   'qual_th': 36566,
#   'share_th': 33008},
#  {'id': 129,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.31978688682689227,
#   'fitness': 0.31978688682689227,
#   'human_shares': 3,
#   'bot_shares': 0,
#   'spread_via_agents': [5312, 4340, 9964],
#   'qual_th': 57865,
#   'share_th': 96401},
#  {'id': 130,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.21362149121120977,
#   'fitness': 0.21362149121120977,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1753],
#   'qual_th': 41181,
#   'share_th': 36945},
#  {'id': 131,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6707967406921135,
#   'fitness': 0.6707967406921135,
#   'human_shares': 3,
#   'bot_shares': 0,
#   'spread_via_agents': [1261, 1545, 7502],
#   'qual_th': 95173,
#   'share_th': 98268},
#  {'id': 132,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.24172820800638728,
#   'fitness': 0.24172820800638728,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7623],
#   'qual_th': 45883,
#   'share_th': 40841},
#  {'id': 133,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.15053119367242773,
#   'fitness': 0.15053119367242773,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [665],
#   'qual_th': 30403,
#   'share_th': 27671},
#  {'id': 134,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.06637016771545579,
#   'fitness': 0.06637016771545579,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [9335],
#   'qual_th': 14574,
#   'share_th': 13342},
#  {'id': 135,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.10651273202347367,
#   'fitness': 0.10651273202347367,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3228],
#   'qual_th': 22274,
#   'share_th': 20440},
#  {'id': 136,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7971836038644644,
#   'fitness': 0.7971836038644644,
#   'human_shares': 108,
#   'bot_shares': 0,
#   'spread_via_agents': [6600,
#    5963,
#    5142,
#    7475,
#    8907,
#    4183,
#    6161,
#    4917,
#    7059,
#    7091,
#    5379,
#    2010,
#    5598,
#    6923,
#    7334,
#    3039,
#    9800,
#    7439,
#    990,
#    2659,
#    5485,
#    3570,
#    8115,
#    3480,
#    5232,
#    1602,
#    5906,
#    3393,
#    4376,
#    711,
#    951,
#    5120,
#    6680,
#    3544,
#    8341,
#    2077,
#    6157,
#    8788,
#    1404,
#    1671,
#    7752,
#    961,
#    3405,
#    8205,
#    6135,
#    2953,
#    8767,
#    7222,
#    4963,
#    496,
#    3489,
#    4960,
#    4117,
#    9695,
#    2276,
#    2152,
#    198,
#    7554,
#    4819,
#    4392,
#    4983,
#    8349,
#    6605,
#    3039,
#    1399,
#    2288,
#    7042,
#    4117,
#    3189,
#    8333,
#    216,
#    9266,
#    7146,
#    9195,
#    1789,
#    9721,
#    2462,
#    1714,
#    1985,
#    7655,
#    2882,
#    5958,
#    3422,
#    3845,
#    9613,
#    3081,
#    46,
#    2723,
#    531,
#    1351,
#    3170,
#    7779,
#    7955,
#    6906,
#    5609,
#    2927,
#    9017,
#    3151,
#    5610,
#    6186,
#    7470,
#    8024,
#    3624,
#    9727,
#    4316,
#    3566,
#    8876,
#    531],
#   'qual_th': 102175,
#   'share_th': 106391},
#  {'id': 137,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1675215732483586,
#   'fitness': 0.1675215732483586,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7517],
#   'qual_th': 33322,
#   'share_th': 30204},
#  {'id': 138,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.34043667589862847,
#   'fitness': 0.34043667589862847,
#   'human_shares': 12,
#   'bot_shares': 0,
#   'spread_via_agents': [8315,
#    1808,
#    8743,
#    5942,
#    1237,
#    2427,
#    3020,
#    9630,
#    3960,
#    2685,
#    5721,
#    5632],
#   'qual_th': 60708,
#   'share_th': 104739},
#  {'id': 139,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1625677218664784,
#   'fitness': 0.1625677218664784,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4043],
#   'qual_th': 32444,
#   'share_th': 29431},
#  {'id': 140,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5515626180331364,
#   'fitness': 0.5515626180331364,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [

#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5735063563246008,
#   'fitness': 0.5735063563246008,
#   'human_shares': 8,
#   'bot_shares': 0,
#   'spread_via_agents': [4680, 8025, 7356, 865, 7749, 5034, 4315, 6479],
#   'qual_th': 87383,
#   'share_th': 103709},
#  {'id': 164,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.12655055447640562,
#   'fitness': 0.12655055447640562,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [198],
#   'qual_th': 26049,
#   'share_th': 23851},
#  {'id': 165,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.9127320320113812,
#   'fitness': 0.9127320320113812,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5496],
#   'qual_th': 105681,
#   'share_th': 84230},
#  {'id': 166,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.043674139063611506,
#   'fitness': 0.043674139063611506,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1197],
#   'qual_th': 10015,
#   'share_th': 9000},
#  {'id': 167,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.308940815613574,
#   'fitness': 0.308940815613574,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8765],
#   'qual_th': 56289,
#   'share_th': 49299},
#  {'id': 168,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7029200838924647,
#   'fitness': 0.7029200838924647,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [3800, 8224],
#   'qual_th': 97289,
#   'share_th': 94077},
#  {'id': 169,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.7581639268908703,
#   'fitness': 0.7581639268908703,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [4715, 3660],
#   'qual_th': 100365,
#   'share_th': 94465},
#  {'id': 170,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.22474368576879578,
#   'fitness': 0.22474368576879578,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1790],
#   'qual_th': 43070,
#   'share_th': 38511},
#  {'id': 171,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.12299429969040465,
#   'fitness': 0.12299429969040465,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4396],
#   'qual_th': 25392,
#   'share_th': 23257},
#  {'id': 172,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.24300158812015016,
#   'fitness': 0.24300158812015016,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5138],
#   'qual_th': 46105,
#   'share_th': 41019},
#  {'id': 173,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.4306182920063615,
#   'fitness': 0.4306182920063615,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [6446],
#   'qual_th': 72391,
#   'share_th': 61667},
#  {'id': 174,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.21934054295164718,
#   'fitness': 0.21934054295164718,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5402],
#   'qual_th': 42170,
#   'share_th': 37773},
#  {'id': 175,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.08226955754649523,
#   'fitness': 0.08226955754649523,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1715],
#   'qual_th': 17650,
#   'share_th': 16207},
#  {'id': 176,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6773938316699083,
#   'fitness': 0.6773938316699083,
#   'human_shares': 4,
#   'bot_shares': 0,
#   'spread_via_agents': [1651, 7332, 4672, 9058],
#   'qual_th': 95613,
#   'share_th': 100454},
#  {'id': 177,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.11010730798460733,
#   'fitness': 0.11010730798460733,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3954],
#   'qual_th': 22942,
#   'share_th': 21044},
#  {'id': 178,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5701131271065143,
#   'fitness': 0.5701131271065143,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [4365, 4068],
#   'qual_th': 87085,
#   'share_th': 92782},
#  {'id': 179,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1848293684683906,
#   'fitness': 0.1848293684683906,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3666],
#   'qual_th': 36274,
#   'share_th': 32757},
#  {'id': 180,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.12414701561221975,
#   'fitness': 0.12414701561221975,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8831],
#   'qual_th': 25599,
#   'share_th': 23447},
#  {'id': 181,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.20776111362847471,
#   'fitness': 0.20776111362847471,
#   'human_shares': 3,
#   'bot_shares': 0,
#   'spread_via_agents': [8102, 6971, 1592],
#   'qual_th': 40214,
#   'share_th': 95769},
#  {'id': 182,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.8867177464164698,
#   'fitness': 0.8867177464164698,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4447],
#   'qual_th': 105108,
#   'share_th': 83875},
#  {'id': 183,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.019277974283268384,
#   'fitness': 0.019277974283268384,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [5187, 2978],
#   'qual_th': 5104,
#   'share_th': 84837},
#  {'id': 184,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.46688151503917197,
#   'fitness': 0.46688151503917197,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2035],
#   'qual_th': 76542,
#   'share_th': 64704},
#  {'id': 185,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.568314124755777,
# ...
#  {'id': 932,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.20640528507280909,
#   'fitness': 0.20640528507280909,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1119],
#   'qual_th': 40007,
#   'share_th': 35943},
#  {'id': 933,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.654191219678699,
#   'fitness': 0.654191219678699,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7662],
#   'qual_th': 94003,
#   'share_th': 76806},
#  {'id': 934,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.15962142228008713,
#   'fitness': 0.15962142228008713,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [6557],
#   'qual_th': 31960,
#   'share_th': 29015},
#  {'id': 935,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.21281760834141827,
#   'fitness': 0.21281760834141827,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [9411, 3079],
#   'qual_th': 41038,
#   'share_th': 87360},
#  {'id': 936,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1050090562988314,
#   'fitness': 0.1050090562988314,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7504],
#   'qual_th': 22012,
#   'share_th': 20203},
#  {'id': 937,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.29879586058442364,
#   'fitness': 0.29879586058442364,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8063],
#   'qual_th': 54761,
#   'share_th': 48096},
#  {'id': 938,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.5099022949513925,
#   'fitness': 0.5099022949513925,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7244],
#   'qual_th': 81295,
#   'share_th': 68087},
#  {'id': 939,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1743013290525297,
#   'fitness': 0.1743013290525297,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [658, 5193],
#   'qual_th': 34495,
#   'share_th': 86727},
#  {'id': 940,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3924063027729279,
#   'fitness': 0.3924063027729279,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [6741],
#   'qual_th': 67690,
#   'share_th': 58146},
#  {'id': 941,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.07088373845098983,
#   'fitness': 0.07088373845098983,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [144],
#   'qual_th': 15460,
#   'share_th': 14160},
#  {'id': 942,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.04042121369321183,
#   'fitness': 0.04042121369321183,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1632],
#   'qual_th': 9376,
#   'share_th': 8391},
#  {'id': 943,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.11854025088947207,
#   'fitness': 0.11854025088947207,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4241],
#   'qual_th': 24582,
#   'share_th': 22517},
#  {'id': 944,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.08974473848101328,
#   'fitness': 0.08974473848101328,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [632, 9523],
#   'qual_th': 19084,
#   'share_th': 85441},
#  {'id': 945,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.02348774475846971,
#   'fitness': 0.02348774475846971,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8922],
#   'qual_th': 6018,
#   'share_th': 5134},
#  {'id': 946,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3290935174972667,
#   'fitness': 0.3290935174972667,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3188],
#   'qual_th': 59168,
#   'share_th': 51571},
#  {'id': 947,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3657170016709689,
#   'fitness': 0.3657170016709689,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3423],
#   'qual_th': 64224,
#   'share_th': 55515},
#  {'id': 948,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6804266393606179,
#   'fitness': 0.6804266393606179,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [3500, 2787],
#   'qual_th': 95801,
#   'share_th': 93896},
#  {'id': 949,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3320271586115512,
#   'fitness': 0.3320271586115512,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5635],
#   'qual_th': 59561,
#   'share_th': 51865},
#  {'id': 950,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.11952302813708426,
#   'fitness': 0.11952302813708426,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4213],
#   'qual_th': 24743,
#   'share_th': 22669},
#  {'id': 951,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6056337829838796,
#   'fitness': 0.6056337829838796,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7858],
#   'qual_th': 90172,
#   'share_th': 74222},
#  {'id': 952,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.48483040011803646,
#   'fitness': 0.48483040011803646,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [8679, 5035],
#   'qual_th': 78547,
#   'share_th': 91700},
#  {'id': 953,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6590746783863275,
#   'fitness': 0.6590746783863275,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3873],
#   'qual_th': 94372,
#   'share_th': 77065},
#  {'id': 954,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.758647433889795,
#   'fitness': 0.758647433889795,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5903],
#   'qual_th': 100394,
#   'share_th': 80918},
#  {'id': 955,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.023935318412394935,
#   'fitness': 0.023935318412394935,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3621],
#   'qual_th': 6129,
#   'share_th': 5245},
#  {'id': 956,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6048794974984788,
#   'fitness': 0.6048794974984788,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8168],
#   'qual_th': 90100,
#   'share_th': 74173},
#  {'id': 957,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.06721685826107904,
#   'fitness': 0.06721685826107904,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1178],
#   'qual_th': 14749,
#   'share_th': 13504},
#  {'id': 958,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.10593346218471855,
#   'fitness': 0.10593346218471855,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7197],
#   'qual_th': 22171,
#   'share_th': 20348},
#  {'id': 959,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.2531855953466666,
#   'fitness': 0.2531855953466666,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2734],
#   'qual_th': 47713,
#   'share_th': 42364},
#  {'id': 960,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.28649735399506937,
#   'fitness': 0.28649735399506937,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [5598],
#   'qual_th': 52976,
#   'share_th': 46672},
#  {'id': 961,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.2953395199012322,
#   'fitness': 0.2953395199012322,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [3466],
#   'qual_th': 54235,
#   'share_th': 47672},
#  {'id': 962,
#   'is_by_bot': 1.0,
#   'phi': 1,
#   'quality': 0,
#   'fitness': 0.9242488184686831,
#   'human_shares': 30,
#   'bot_shares': 1,
#   'spread_via_agents': [10064,
#    6618,
#    3341,
#    1962,
#    5222,
#    2697,
#    7024,
#    5820,
#    5893,
#    8189,
#    884,
#    7901,
#    7425,
#    3441,
#    2205,
#    5798,
#    656,
#    1130,
#    454,
#    1721,
#    3750,
#    4845,
#    7190,
#    3213,
#    9089,
#    3469,
#    7602,
#    5966,
#    6691,
#    8028,
#    9741],
#   'qual_th': 10,
#   'share_th': 106035},
#  {'id': 963,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1265400649236863,
#   'fitness': 0.1265400649236863,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2056],
#   'qual_th': 26044,
#   'share_th': 23848},
#  {'id': 964,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.19916084032377335,
#   'fitness': 0.19916084032377335,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1309],
#   'qual_th': 38778,
#   'share_th': 34895},
#  {'id': 965,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.35996834294547675,
#   'fitness': 0.35996834294547675,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8222],
#   'qual_th': 63411,
#   'share_th': 54889},
#  {'id': 966,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.42048550152357655,
#   'fitness': 0.42048550152357655,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [4395],
#   'qual_th': 71135,
#   'share_th': 60747},
#  {'id': 967,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6081566117250354,
#   'fitness': 0.6081566117250354,
#   'human_shares': 17,
#   'bot_shares': 0,
#   'spread_via_agents': [9794,
#    2807,
#    559,
#    1451,
#    1929,
#    4911,
#    6923,
#    6358,
#    4434,
#    6322,
#    1470,
#    8826,
#    3728,
#    3959,
#    8461,
#    2495,
#    8584],
#   'qual_th': 90391,
#   'share_th': 105445},
#  {'id': 968,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.17951528375372294,
#   'fitness': 0.17951528375372294,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [7646, 4674],
#   'qual_th': 35349,
#   'share_th': 86807},
#  {'id': 969,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.06660351026695843,
#   'fitness': 0.06660351026695843,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [9392],
#   'qual_th': 14626,
#   'share_th': 13390},
#  {'id': 970,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.1582709260342242,
#   'fitness': 0.1582709260342242,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8472],
#   'qual_th': 31739,
#   'share_th': 28820},
#  {'id': 971,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.07283313756553433,
#   'fitness': 0.07283313756553433,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [

#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6980310943234738,
#   'fitness': 0.6980310943234738,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [3425, 7773],
#   'qual_th': 96969,
#   'share_th': 94036},
#  {'id': 995,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.6678528156598913,
#   'fitness': 0.6678528156598913,
#   'human_shares': 2,
#   'bot_shares': 0,
#   'spread_via_agents': [9736, 134],
#   'qual_th': 94994,
#   'share_th': 93794},
#  {'id': 996,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.41434999389290494,
#   'fitness': 0.41434999389290494,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [8286],
#   'qual_th': 70410,
#   'share_th': 60206},
#  {'id': 997,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.3523834839160116,
#   'fitness': 0.3523834839160116,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [2846],
#   'qual_th': 62314,
#   'share_th': 54034},
#  {'id': 998,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.08639565041551278,
#   'fitness': 0.08639565041551278,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [1989],
#   'qual_th': 18461,
#   'share_th': 16961},
#  {'id': 999,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.37727652725450844,
#   'fitness': 0.37727652725450844,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [7243],
#   'qual_th': 65767,
#   'share_th': 56681},
#  {'id': 1000,
#   'is_by_bot': 0.0,
#   'phi': 1,
#   'quality': 0.36116205554804726,
#   'fitness': 0.36116205554804726,
#   'human_shares': 1,
#   'bot_shares': 0,
#   'spread_via_agents': [9592],
#   'qual_th': 63582,
#   'share_th': 55017},
#  ...]

# %% [markdown]
# ## Deg histogram of the network

# %%
graph = G
vertices = range(len(graph.vs)) #vertices index
degs = graph.degree(vertices, mode='in', loops=False)
plt.hist(degs)
# Out:
# (array([7136., 1708.,  633.,  265.,  162.,   87.,   56.,   32.,   16.,
#           11.]),
#  array([   4. ,  186.9,  369.8,  552.7,  735.6,  918.5, 1101.4, 1284.3,
#         1467.2, 1650.1, 1833. ]),
#  <BarContainer object of 10 artists>)

# %%
graph = G
bots = [n for n in graph.vs if n['bot']==1]
humans = [n for n in graph.vs if n['bot']==0] #vertices index
bot_degs = graph.degree(bots, mode='in', loops=False)
human_degs = graph.degree(humans, mode='in', loops=False)

# %%
fig,ax = plt.subplots()
alpha=0.6
ax.set_yscale('log')
ax.set_xscale('log')
ax.hist(human_degs, label='human', alpha=alpha)
ax.hist(bot_degs, label='bot', alpha=alpha)

ax.legend()
plt.title('Degree distribution (low infiltration gamma 0.005 beta 0.01)')
plt.xlabel('In-degree')
plt.ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %% [markdown]
# # Plot number of shares a meme gets vs the indeg of the spreading channel
# Let's say hubs are those with indeg>=15.

# %% [markdown]
# ## Bot memes

# %%
shares = [meme['human_shares'] + meme['bot_shares'] for meme in verbose['all_memes'] if meme['is_by_bot']==1]

# %%
shares=[]
avg_indegs = []
largest_indegs=[]
for meme in verbose['all_memes'][0]: #since verbose['all_memes'] is a list over multiple simulations
    if meme['is_by_bot']==1:
        shares+= [meme['human_shares'] + meme['bot_shares']]
        spread_through= [int(node) for node in meme['spread_via_agents']]
        indegs = graph.degree(spread_through, mode=mode, loops=False)
        avg_indegs += [np.mean(indegs)]
        largest_indegs += [max(indegs)]

# %%
plt.scatter(avg_indegs, shares)
plt.title('Number of shares vs. Indeg of spreading channel (Memes by bots)')
plt.yscale('log')
plt.xlabel('Avg in degree of nodes spreading this meme')
plt.ylabel('shares')
# Out:
# Text(0, 0.5, 'shares')

# %%
plt.scatter(largest_indegs, shares)
plt.title('Number of shares vs. Indeg of spreading channel (Memes by bots)')
plt.xlabel('The largest in-degree of node spreading this meme')
plt.ylabel('shares')
plt.yscale('log')

# %% [markdown]
# --> Seems like every meme goes through a hub

# %% [markdown]
# ## Plot for hubs and no targeting

# %%
def numshares_vs_indeg(exp_no):
    mode='igraph'
    network = os.path.join(DATA_PATH, mode, 'vary_targetgamma', "network_%s.gml" %EXP_NETWORK[exp_no])
    fpath = os.path.join(TRACKING_DIR,'%s.json.gz' %exp_no)
    G = ig.Graph.Read_GML(network)
    verbose = utils.read_json_compressed(fpath)
#     print('network: ', network)
    deg_mode='in'
    shares=[]
    avg_indegs = []
    largest_indegs=[]
    all_indegs = []
#     print(verbose.keys())
    for meme in verbose['all_memes'][0]: #since verbose['all_memes'] is a list over multiple simulations
        if meme['is_by_bot']==1:
            shares+= [meme['human_shares'] + meme['bot_shares']]
            spread_through= [int(node) for node in meme['spread_via_agents']]
            indegs = G.degree(spread_through, mode=deg_mode, loops=False)
            all_indegs +=[indegs]
            avg_indegs += [np.mean(indegs)]
            largest_indegs += [max(indegs)]
    return shares, all_indegs, avg_indegs, largest_indegs

# %%
nohub = 'none_02'
hub = 'hubs_02'
shares, all_indegs, avg_indegs, largest_indegs = numshares_vs_indeg(nohub)
hubshares, huball_indegs, hubavg_indegs, hublargest_indegs = numshares_vs_indeg(hub)

# %%
fig, (ax1,ax2)= plt.subplots(1,2, sharey=True, sharex=True, figsize=(8,5))
ax1.scatter(avg_indegs, shares)
ax1.set_title('No targeting')
ax1.set_xlabel('Avg in-degree of nodes spreading this meme')
ax1.set_ylabel('shares')
ax1.set_yscale('log')

ax2.scatter(hubavg_indegs, hubshares)
ax2.set_title('Hubs targeting')
ax2.set_xlabel('Avg in-degree of nodes spreading this meme')
ax2.set_ylabel('shares')

fig.suptitle('Number of shares vs. Indeg of spreading channel (Memes by bots)')
fig.tight_layout()

# %% [markdown]
# ## CCDF

# %%
def indeg_spreading_channels(exp_no):
    mode='igraph'
    network = os.path.join(DATA_PATH, mode, 'vary_targetgamma', "network_%s.gml" %EXP_NETWORK[exp_no])
    fpath = os.path.join(TRACKING_DIR,'%s.json.gz' %exp_no)
    G = ig.Graph.Read_GML(network)
    verbose = utils.read_json_compressed(fpath)
#     print('network: ', network)
    deg_mode='in'
    
    bot_largest_spreading_nodes = []
    human_largest_spreading_nodes = []
    for meme in verbose['all_memes'][0]: #since verbose['all_memes'] is a list over multiple simulations

        spread_through= [int(node) for node in meme['spread_via_agents']]
        indegs = G.degree(spread_through, mode=deg_mode, loops=False)
        largest_indeg = max(indegs)
        if meme['is_by_bot']==1:
            bot_largest_spreading_nodes += [largest_indeg]  
        else:
            human_largest_spreading_nodes += [largest_indeg]

    return bot_largest_spreading_nodes, human_largest_spreading_nodes

# %%
nohub = 'none_02'
hub = 'hubs_02'
bot_spread, human_spread= indeg_spreading_channels(nohub)
hubs_bot_spread, hubs_human_spread= indeg_spreading_channels(hub)

# %%
figure, (ax1, ax2) = plt.subplots(1,2, figsize=(10, 5), sharex=True)

sns.ecdfplot(ax=ax1, data = bot_spread, complementary=True, label = 'bot memes')
sns.ecdfplot(ax=ax1, data = human_spread, complementary=True, label = 'human memes')
ax1.legend()
# ax1.set_xscale('log')

sns.ecdfplot(ax=ax2, data = hubs_bot_spread, complementary=True, label = 'bot memes')
sns.ecdfplot(ax=ax2, data = hubs_human_spread, complementary=True, label = 'human memes')

ax1.set_title('no targeting')
ax2.set_title('hubs targeting')
ax1.set_xlabel('largest in-deg of spreading nodes')
ax2.set_xlabel('largest in-deg of spreading nodes')

figure.suptitle('CCDF: Largest in-deg of spreading nodes (across whole simulation)')
# ax.set_xlim([0, 1])
# Out:
# Text(0.5, 0.98, 'CCDF: Largest in-deg of spreading nodes (across whole simulation)')

# %% [markdown]
# # Separate between hub nodes and non-hub nodes

# %%
exp_no='none_04'
network = os.path.join(DATA_PATH, mode, 'vary_targetgamma', "network_%s.gml" %EXP_NETWORK[exp_no])
fpath = os.path.join(TRACKING_DIR,'%s.json.gz' %exp_no)
G = ig.Graph.Read_GML(network)
verbose = utils.read_json_compressed(fpath)
print('network: ', network)

hub_meme_share = []
nonehub_meme_share = []
hub_size=300

for meme in verbose['all_memes'][0]: #since verbose['all_memes'] is a list over multiple simulations
    if meme['is_by_bot']==1:
        shares = meme['human_shares'] + meme['bot_shares']
        spread_through= [int(node) for node in meme['spread_via_agents']]
        indegs = graph.degree(spread_through, mode=mode, loops=False)
        viahubs = [i for i in indegs if i>=hub_size]
        if len(viahubs)>0:
            #meme went through at least 1 hub
            hub_meme_share += [shares]
        else:
            nonehub_meme_share += [shares]
# Out:
# network:  /N/slate/baotruon/marketplace/data/igraph/vary_targetgamma/network_08.gml
# /N/u/baotruon/Carbonate/miniconda3/envs/graph/lib/python3.7/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Partial string matches of enum members are deprecated since igraph 0.9.3; use strings that identify an enum member unambiguously.
#   app.launch_new_instance()

# %%
alpha=0.6
fig, ax= plt.subplots()
ax.hist(hub_meme_share, label='via hub', alpha=alpha)
ax.hist(nonehub_meme_share, label='not via hub', alpha=alpha)
ax.legend()
ax.set_xlabel('Shares')
ax.set_ylabel('Freq')
ax.set_title('Distribution of shares of bot memes')
# Out:
# Text(0.5, 1.0, 'Distribution of shares of bot memes')

# %% [markdown]
# ## plot for 2 strategies

# %%
def shares_separate_by_hubs(exp_no, hub_size=1000, allshare=True):
    mode='igraph'
    network = os.path.join(DATA_PATH, mode, 'vary_targetgamma', "network_%s.gml" %EXP_NETWORK[exp_no])
    fpath = os.path.join(TRACKING_DIR,'%s.json.gz' %exp_no)
    G = ig.Graph.Read_GML(network)
    verbose = utils.read_json_compressed(fpath)
    print('network: ', network)
    deg_mode='in'
    hub_meme_share = []
    nonehub_meme_share = []

    for meme in verbose['all_memes'][0]: #since verbose['all_memes'] is a list over multiple simulations
        if meme['is_by_bot']==1:
            if allshare is True:
                shares = meme['human_shares'] + meme['bot_shares']
            else:
                shares = meme['human_shares']
            spread_through= [int(node) for node in meme['spread_via_agents']]
            indegs = G.degree(spread_through, mode=deg_mode, loops=False)
            viahubs = [i for i in indegs if i>=hub_size]
            if len(viahubs)>0:
                #meme went through at least 1 hub
                hub_meme_share += [shares]
            else:
                nonehub_meme_share += [shares]
    return hub_meme_share, nonehub_meme_share

# %% [markdown]
# All shares

# %%
allshare=True
nohub = 'none_04'
hub = 'hubs_04'
hub_meme_share, nonehub_meme_share = shares_separate_by_hubs(nohub, allshare=allshare)
hubs_hub_meme_share, hubs_nonehub_meme_share = shares_separate_by_hubs(hub, allshare=allshare)
# Out:
# network:  /N/slate/baotruon/marketplace/data/igraph/vary_targetgamma/network_08.gml
# /N/u/baotruon/Carbonate/miniconda3/envs/graph/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: Partial string matches of enum members are deprecated since igraph 0.9.3; use strings that identify an enum member unambiguously.
# network:  /N/slate/baotruon/marketplace/data/igraph/vary_targetgamma/network_18.gml

# %%
alpha=0.6
fig, (ax1,ax2)= plt.subplots(1,2, sharex=True, sharey=True, figsize=(8,5))
ax1.hist(hub_meme_share, label='via hub', alpha=alpha)
ax1.hist(nonehub_meme_share, label='not via hub', alpha=alpha)
ax1.legend()
ax1.set_xlabel('Shares')
ax1.set_ylabel('Freq')
ax1.set_title('no targeting')
ax1.set_yscale('log')
ax1.set_xscale('log')
ax2.hist(hubs_hub_meme_share, label='via hub', alpha=alpha)
ax2.hist(hubs_nonehub_meme_share, label='not via hub', alpha=alpha)
ax2.set_title('hubs targeting')
ax2.set_xlabel('Shares')

fig.suptitle('Distribution of shares of bot memes (hubsize=1000, all shares)')
fig.tight_layout()

# %% [markdown]
# Only human shares

# %%
allshare=False
nohub = 'none_04'
hub = 'hubs_04'
hub_meme_share, nonehub_meme_share = shares_separate_by_hubs(nohub, allshare=allshare)
hubs_hub_meme_share, hubs_nonehub_meme_share = shares_separate_by_hubs(hub, allshare=allshare)
# Out:
# network:  /N/slate/baotruon/marketplace/data/igraph/vary_targetgamma/network_08.gml
# /N/u/baotruon/Carbonate/miniconda3/envs/graph/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: Partial string matches of enum members are deprecated since igraph 0.9.3; use strings that identify an enum member unambiguously.
# network:  /N/slate/baotruon/marketplace/data/igraph/vary_targetgamma/network_18.gml

# %%
alpha=0.6
fig, (ax1,ax2)= plt.subplots(1,2, sharex=True, sharey=True, figsize=(8,5))
ax1.hist(hub_meme_share, label='via hub', alpha=alpha)
ax1.hist(nonehub_meme_share, label='not via hub', alpha=alpha)
ax1.legend()
ax1.set_xlabel('Shares')
ax1.set_ylabel('Freq')
ax1.set_title('no targeting')
ax1.set_yscale('log')
ax1.set_xscale('log')
ax2.hist(hubs_hub_meme_share, label='via hub', alpha=alpha)
ax2.hist(hubs_nonehub_meme_share, label='not via hub', alpha=alpha)
ax2.set_title('hubs targeting')
ax2.set_xlabel('Shares')

fig.suptitle('Distribution of shares of bot memes (hubsize=1000, human shares)')
fig.tight_layout()

# %% [markdown]
# ## Human vs bot memes separated by hubs

# %%
def shares_separate_by_hubs(exp_no, hub_size=1000, allshare=True):
    mode='igraph'
    network = os.path.join(DATA_PATH, mode, 'vary_targetgamma', "network_%s.gml" %EXP_NETWORK[exp_no])
    fpath = os.path.join(TRACKING_DIR,'%s.json.gz' %exp_no)
    G = ig.Graph.Read_GML(network)
    verbose = utils.read_json_compressed(fpath)
    print('network: ', network)
    deg_mode='in'
    bot_hub_memeshare = []
    bot_nonehub_memeshare = []
    
    human_hub_memeshare = []
    human_nonehub_memeshare = []
    
    for meme in verbose['all_memes'][0]: #since verbose['all_memes'] is a list over multiple simulations
        spread_through= [int(node) for node in meme['spread_via_agents']]
        indegs = G.degree(spread_through, mode=deg_mode, loops=False)
        viahubs = [i for i in indegs if i>=hub_size]
        if allshare is True:
            shares = meme['human_shares'] + meme['bot_shares']
        else:
            shares = meme['human_shares']
                
        if meme['is_by_bot']==1: 
            if len(viahubs)>0:
                #meme went through at least 1 hub
                bot_hub_memeshare += [shares]
            else:
                bot_nonehub_memeshare += [shares]
        else:
            if len(viahubs)>0:
                #meme went through at least 1 hub
                human_hub_memeshare += [shares]
            else:
                human_nonehub_memeshare += [shares]
    return bot_hub_memeshare, bot_nonehub_memeshare, human_hub_memeshare, human_nonehub_memeshare

# %%
allshare=False
nohub = 'none_02'
hub = 'hubs_02'
bot_hub_memeshare, bot_nonehub_memeshare, human_hub_memeshare, human_nonehub_memeshare = shares_separate_by_hubs(nohub, allshare=False)
# Out:
# network:  /N/slate/baotruon/marketplace/data/igraph/vary_targetgamma/network_05.gml

# %%
alpha=0.6
fig, (ax1,ax2)= plt.subplots(1,2, sharex=True, sharey=True, figsize=(8,5))
ax1.hist(human_hub_memeshare, label='human', alpha=alpha)
ax1.hist(bot_hub_memeshare, label='bot', alpha=alpha)

ax1.legend()
ax1.set_xlabel('Shares')
ax1.set_ylabel('Freq')
ax1.set_title('via hubs')
ax1.set_yscale('log')
ax1.set_xscale('log')
ax2.hist(human_nonehub_memeshare, label='human', alpha=alpha)
ax2.hist(bot_nonehub_memeshare, label='bot', alpha=alpha)

ax2.set_title('not via hubs')
ax2.set_xlabel('Shares')

fig.suptitle('No targeting: Distribution of meme shares (hubsize=1000, human shares)')
fig.tight_layout()

# %%
bot_hub_memeshare, bot_nonehub_memeshare, human_hub_memeshare, human_nonehub_memeshare = shares_separate_by_hubs(hub, allshare=False)
# Out:
# network:  /N/slate/baotruon/marketplace/data/igraph/vary_targetgamma/network_15.gml

# %%
alpha=0.6
fig, (ax1,ax2)= plt.subplots(1,2, sharex=True, sharey=True, figsize=(8,5))
ax1.hist(human_hub_memeshare, label='human', alpha=alpha)
ax1.hist(bot_hub_memeshare, label='bot', alpha=alpha)

ax1.legend()
ax1.set_xlabel('Shares')
ax1.set_ylabel('Freq')
ax1.set_title('via hubs')
ax1.set_yscale('log')
ax1.set_xscale('log')
ax2.hist(human_nonehub_memeshare, label='human', alpha=alpha)
ax2.hist(bot_nonehub_memeshare, label='bot', alpha=alpha)

ax2.set_title('not via hubs')
ax2.set_xlabel('Shares')

fig.suptitle('Hubs targeting: Distribution of meme shares (hubsize=1000, human shares)')
fig.tight_layout()

# %%
allshare=False
nohub = 'none_02'
hub = 'hubs_02'
bot_hub_memeshare1, bot_nonehub_memeshare1, human_hub_memeshare1, human_nonehub_memeshare1 = shares_separate_by_hubs(nohub, allshare=False)
# Out:
# network:  /N/slate/baotruon/marketplace/data/igraph/vary_targetgamma/network_05.gml

# %%
bot_hub_memeshare2, bot_nonehub_memeshare2, human_hub_memeshare2, human_nonehub_memeshare2 = shares_separate_by_hubs(hub, allshare=False)
# Out:
# network:  /N/slate/baotruon/marketplace/data/igraph/vary_targetgamma/network_15.gml

# %%
alpha=0.6
fig, (ax1,ax2)= plt.subplots(1,2, sharex=True, sharey=True, figsize=(8,5))
ax1.hist(bot_nonehub_memeshare1, label='not via hub (no target)', alpha=alpha)
# ax1.hist(bot_hub_memeshare1, label='via hubs (no target)', alpha=alpha)
# ax1.hist(bot_nonehub_memeshare2, label='not via hub (target)', alpha=alpha)
ax1.hist(bot_hub_memeshare2, label='via hubs (target)', alpha=alpha)

ax1.legend()
ax1.set_xlabel('Shares')
ax1.set_ylabel('Freq')
ax1.set_title('Bot memes')
ax1.set_yscale('log')
ax1.set_xscale('log')
ax2.hist(human_nonehub_memeshare1, label='not via hub (no target)', alpha=alpha)
ax2.hist(human_hub_memeshare1, label='via hubs (no target)', alpha=alpha)
ax2.hist(human_nonehub_memeshare2, label='not via hub (target)', alpha=alpha)
ax2.hist(human_hub_memeshare2, label='via hubs (target)', alpha=alpha)

ax2.set_title('Human memes')
ax2.set_xlabel('Shares')
ax2.legend()
fig.suptitle('Hubs targeting: Distribution of meme shares (hubsize=1000, human shares, beta 0.01 gamma 0.1)')
fig.tight_layout()

# %% [markdown]
# # Degree distribution

# %%
def plot_degree_dist(graph, mode='in'):
    vertices = range(len(graph.vs)) #vertices index
    degs = graph.degree(vertices, mode=mode, loops=False)
    degs = dict(collections.Counter(degs))
    k_per_deg = dict(sorted(degs.items()))
    p_k = {deg: num/len(vertices) for deg,num in k_per_deg.items()}
    plt.scatter(p_k.keys(),p_k.values())
    
    plt.yscale('log')
    plt.xscale('log')
    plt.ylabel('p_k')
    plt.xlabel('k')
    plt.title('Degree distribution (%s degree)' %mode)
    plt.show()

# %%
plot_degree_dist(G, mode='in')

# %% [markdown]
# Seems like a lot of bad content spread through hub bots

# %% [markdown]
# ## Degree of bots and humans

# %%
def hum_bot_degree(graph, deg_mode='in'):
    bots =[]
    humans = []
    for vertice in graph.vs:
        if vertice['bot']==0:
            humans += [graph.degree(vertice, mode=mode, loops=False)]
        else:
            bots += [graph.degree(vertice, mode=mode, loops=False)]
    return bots,humans

# %%
deg_mode='in'
bot_degs, human_degs= hum_bot_degree(graph, deg_mode=deg_mode)
# Out:
# /N/u/baotruon/Carbonate/miniconda3/envs/graph/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Partial string matches of enum members are deprecated since igraph 0.9.3; use strings that identify an enum member unambiguously.
#
# /N/u/baotruon/Carbonate/miniconda3/envs/graph/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Partial string matches of enum members are deprecated since igraph 0.9.3; use strings that identify an enum member unambiguously.

# %%
alpha=0.6
plt.hist(human_degs, label='human', alpha=alpha)    
plt.hist(bot_degs, label='bot', alpha=alpha)    
plt.yscale('log')
plt.xscale('log')
plt.ylabel('Freq')
plt.xlabel('In degree')
plt.title('Degree distribution (%s degree)' %deg_mode)
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
figure, ax= plt.subplots()

sns.ecdfplot(ax=ax, data = bot_degs, complementary=True, label = 'bot')
sns.ecdfplot(ax=ax, data = human_degs, complementary=True, label = 'human')
ax.legend()
# ax.set_xscale('log')

# %% [markdown]
# --> Yes, bot degrees are concentrated and have size

# %%
figure, ax= plt.subplots()

sns.ecdfplot(ax=ax, data = bot_degs, complementary=True, label = 'bot')
# sns.ecdfplot(ax=ax, data = human_degs, complementary=True, label = 'human')
ax.legend()
# ax.set_xscale('log')

# %% [markdown]
# # Probability of an agent sharing memes from hub

# %% [markdown]
# During the whole simulation

# %%
def meme_largest_deg(exp_no, allshare=True):
    network = os.path.join(DATA_PATH, mode, 'vary_targetgamma', "network_%s.gml" %EXP_NETWORK[exp_no])
    fpath = os.path.join(TRACKING_DIR,'%s.json.gz' %exp_no)
    G = ig.Graph.Read_GML(network)
    verbose = utils.read_json_compressed(fpath)
    print('network: ', network)

    bots = []
    humans = []
    
    
    for meme in verbose['all_memes'][0]: #since verbose['all_memes'] is a list over multiple simulations
        if meme['is_by_bot']==1:
            if allshare is True:
                shares = meme['human_shares'] + meme['bot_shares']
            else:
                shares = meme['human_shares']
            spread_through= [int(node) for node in meme['spread_via_agents']]
            indegs = graph.degree(spread_through, mode=mode, loops=False)
            viahubs = [i for i in indegs if i>=hub_size]
            if len(viahubs)>0:
                #meme went through at least 1 hub
                hub_meme_share += [shares]
            else:
                nonehub_meme_share += [shares]
    return hub_meme_share, nonehub_meme_share

# %%
verbose['all_feeds'][0]
# Out:
# {'65537': [141533,
#   141497,
#   152,
#   141160,
#   107629,
#   141099,
#   141070,
#   140966,
#   77948,
#   140007,
#   139892,
#   139857,
#   139801,
#   139696,
#   129287],
#  '65538': [141467,
#   141160,
#   77948,
#   140463,
#   140744,
#   152,
#   152,
#   139086,
#   107629,
#   152,
#   127555,
#   138234,
#   138094,
#   115806,
#   137041],
#  '5': [113980,
#   141433,
#   98558,
#   141124,
#   107629,
#   141047,
#   140988,
#   39752,
#   140784,
#   140467,
#   140443,
#   140332,
#   140293,
#   113980,
#   152],
#  '32775': [141611,
#   141609,
#   141603,
#   137687,
#   141595,
#   141547,
#   116830,
#   141520,
#   141513,
#   107629,
#   141267,
#   77948,
#   141477,
#   141430,
#   141429],
#  '98314': [141366,
#   141497,
#   141366,
#   77948,
#   141279,
#   141261,
#   107629,
#   140962,
#   136786,
#   133077,
#   133077,
#   77948,
#   39752],
#  '68205': [141611,
#   141609,
#   133077,
#   141578,
#   107629,
#   141575,
#   77948,
#   107629,
#   141556,
#   141555,
#   107629,
#   141545,
#   141538,
#   141535,
#   107629],
#  '100972': [107629,
#   141462,
#   141247,
#   141140,
#   141094,
#   107629,
#   140724,
#   140691,
#   140532,
#   137687,
#   138935,
#   77948,
#   107629,
#   139501,
#   107629],
#  '100976': [133077,
#   141045,
#   141041,
#   140671,
#   107629,
#   107629,
#   140043,
#   138081,
#   39752,
#   139402,
#   152,
#   139303,
#   127555,
#   107629,
#   138989],
#  '35440': [133896,
#   141601,
#   141486,
#   141446,
#   110585,
#   141366,
#   141293,
#   141279,
#   141276,
#   39752,
#   110585,
#   140557,
#   141160,
#   107629,
#   77948],
#  '68208': [77948,
#   107629,
#   141477,
#   141491,
#   107629,
#   141310,
#   141330,
#   141310,
#   141308,
#   141305,
#   141299,
#   141299,
#   141277,
#   107629,
#   141244],
#  '100980': [141575,
#   141503,
#   141397,
#   141319,
#   141305,
#   141233,
#   141199,
#   107629,
#   86983,
#   152,
#   140769,
#   140760,
#   107629,
#   140724,
#   140633],
#  '100986': [137687,
#   141575,
#   77948,
#   107629,
#   141447,
#   141422,
#   141299,
#   141308,
#   141282,
#   141230,
#   141204,
#   141199,
#   77948,
#   141106,
#   107629],
#  '133759': [141533,
#   141497,
#   141283,
#   110585,
#   141070,
#   86983,
#   141036,
#   141023,
#   140931,
#   136786,
#   140768,
#   140652,
#   140659,
#   140557,
#   140328],
#  '35458': [107629,
#   141233,
#   141558,
#   141503,
#   141413,
#   141233,
#   141177,
#   141146,
#   141032,
#   139744,
#   140851,
#   39752,
#   116830,
#   140534,
#   140351],
#  '68230': [141233,
#   141572,
#   141413,
#   141097,
#   141032,
#   140851,
#   139567,
#   140142,
#   127555,
#   138952,
#   139262,
#   109387,
#   138991,
#   118865,
#   129287],
#  '133767': [77948,
#   141555,
#   141545,
#   141503,
#   141501,
#   107629,
#   141491,
#   141465,
#   77948,
#   141424,
#   77948,
#   141299,
#   141284,
#   141267,
#   141303],
#  '101000': [107629,
#   141547,
#   77948,
#   141319,
#   141198,
#   77948,
#   141119,
#   141110,
#   137687,
#   141016,
#   77948,
#   140901,
#   107629,
#   140631,
#   140545],
#  '68232': [141397,
#   141396,
#   141385,
#   141284,
#   140802,
#   77948,
#   123444,
#   107629,
#   140328,
#   140189,
#   152,
#   139402,
#   138650,
#   138605,
#   118865],
#  ...}

# %%
any(map(str.isalpha, 'ab34'))
# Out:
# True

# %%
humans = [agent_id for agent_id in verbose['all_feeds'][0].keys() if any(map(str.isalpha, agent_id)) is False]

# %%
len(humans)
# Out:
# 10006

# %%
sim_num = 1
mode='igraph'
RES_DIR = os.path.join(ABS_PATH,'results', 'vary_thetaphi_1runs_gamma0.005')
TRACKING_DIR = os.path.join(ABS_PATH,'long_results', 'vary_thetaphi_1runs_gamma0.005')

# %%
def prob_spreading_throughhub(exp_no):
    mode='igraph'
    network = os.path.join(DATA_PATH, mode, 'vary_targetgamma', "network_%s.gml" %EXP_NETWORK[exp_no])
    fpath = os.path.join(TRACKING_DIR,'%s.json.gz' %exp_no)
    G = ig.Graph.Read_GML(network)
    verbose = utils.read_json_compressed(fpath)
    deg_mode='in'
    print(network)
    print(fpath)
    bot_memes = []
    human_memes = []
    # humans = [agent_id for agent_id in verbose['all_feeds'][0].keys() if any(map(str.isalpha, agent_id)) is False]
    for agentid, memeids in verbose['all_feeds'][0].items():
        if any(map(str.isalpha, agentid)) is True:
            #skip bots
            continue

        verbose_memes = [meme for meme in verbose['all_memes'][0] if meme['id'] in memeids]
        for meme in verbose_memes:
            spread_through= [int(node) for node in meme['spread_via_agents']]
            indegs = G.degree(spread_through, mode=deg_mode, loops=False)
            largest_indeg = max(indegs)
            if meme['is_by_bot']==1:
                bot_memes += [largest_indeg]
            else:
                human_memes += [largest_indeg]
    return bot_memes, human_memes

# %%
nohub = 'none_02'
hub = 'hubs_02'
botmeme_fname = 'trackhubs_botmemes_gamma0.005.pkl'
humanmeme_fname = 'trackhubs_humanmemes_gamma0.005.pkl'

print('Getting data - %s ... ' %nohub)
bot_memes, human_memes = prob_spreading_throughhub(nohub)
print('Getting data - %s ... ' %hub)
hubs_bot_memes, hubs_human_memes = prob_spreading_throughhub(hub)

# %%
pkl.dump(bot_memes, open('%s_%s.pkl' %(nohub, botmeme_fname), 'wb'))
pkl.dump(human_memes, open('%s_%s.pkl' %(nohub, humanmeme_fname), 'wb'))  

pkl.dump(hubs_bot_memes, open('%s_%s.pkl' %(hub, botmeme_fname), 'wb'))
pkl.dump(hubs_human_memes, open('%s_%s.pkl' %(hub, humanmeme_fname), 'wb'))

# %% [markdown]
# ## Data saved, run from here

# %%
nohub = 'none_02'
hub = 'hubs_02'
botmeme_fname = 'trackhubs_botmemes_gamma0.005.pkl'
humanmeme_fname = 'trackhubs_humanmemes_gamma0.005.pkl'
bot_memes = pkl.load(open('%s_%s' %(nohub, botmeme_fname), 'rb'))
human_memes = pkl.load(open('%s_%s' %(nohub, humanmeme_fname), 'rb'))

hubs_bot_memes = pkl.load(open('%s_%s' %(hub, botmeme_fname), 'rb'))
hubs_human_memes = pkl.load(open('%s_%s' %(hub, humanmeme_fname), 'rb'))

# %%
import seaborn as sns

# %%
figure, (ax1, ax2) = plt.subplots(1,2, figsize=(10, 5), sharex=True)

sns.ecdfplot(ax=ax1, data = bot_memes, complementary=True, label = 'bot memes')
sns.ecdfplot(ax=ax1, data = human_memes, complementary=True, label = 'human memes')
ax1.legend()
ax1.set_xscale('log')

sns.ecdfplot(ax=ax2, data = hubs_bot_memes, complementary=True, label = 'bot memes')
sns.ecdfplot(ax=ax2, data = hubs_human_memes, complementary=True, label = 'human memes')

ax1.set_title('no targeting')
ax2.set_title('hubs targeting')
ax1.set_xlabel('largest in-deg of spreading nodes')
ax2.set_xlabel('largest in-deg of spreading nodes')

figure.suptitle('CCDF: Largest in-deg of spreading nodes (final state)')
# ax.set_xlim([0, 1])
