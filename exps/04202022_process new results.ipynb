# %%
from matplotlib import cm 
import gzip
import matplotlib.pyplot as plt
import csv
import numpy as np 
import glob 
import json
import os
from matplotlib import cm
import infosys.utils as utils 
from collections import defaultdict
cmap = cm.get_cmap('inferno', 10)

# %%
ABS_PATH = '/N/slate/baotruon/marketplace'
DATA_PATH = os.path.join(ABS_PATH, "data")
RES_PATH = os.path.join(ABS_PATH, "results")

all_configs = json.load(open(os.path.join(DATA_PATH,'all_configs.json'),'r'))
config_fpath = os.path.join(DATA_PATH,'all_configs.json')

PLOT_PATH = 'results/plots'

# %%
def read_json_compressed(fpath):
    data=None
    try:
        fin = gzip.open(fpath, 'r')
        json_bytes = fin.read()  
        json_str = json_bytes.decode('utf-8')
        data = json.loads(json_str)
    except Exception as e:
        print(e)
    return data

# %%
pprint = {'gamma':'$\\gamma$','theta': '$\\theta$', 'beta':'$\\beta$', 'phi': '$\phi$', 
        'quality': 'Relative Average Quality', 'discriminative_pow': 'Discriminative Power', 'diversity': 'Diversity'}
    
BETA = [0.0001, 0.0002, 0.0005, 0.001, 0.002, 0.005, 0.02, 0.05, 0.1, 0.2, 0.5]
GAMMA = [0.0001, 0.0002, 0.0005, 0.001, 0.002, 0.005, 0.02, 0.05, 0.1, 0.2, 0.5]
TARGETING = [None, 'hubs', 'partisanship', 'conservative', 'liberal', 'misinformation']
PHI_LIN = list(range(1,11))
THETA = [1,2,4,6,8,10,12,14]

heatmap_config = {'vary_thetagamma': {'x':'theta', 'y':'gamma', 'xvals':THETA, 'yvals':GAMMA},
'vary_phigamma': {'x':'phi', 'y':'gamma', 'xvals':PHI_LIN, 'yvals':GAMMA},
'vary_betagamma': {'x':'beta', 'y':'gamma', 'xvals':BETA, 'yvals':GAMMA},
'vary_thetaphi': {'x':'theta', 'y':'phi', 'xvals':THETA, 'yvals':PHI_LIN}
}

# %%
xticks = {
        'vary_thetagamma': {'vals': THETA, 'label': pprint['theta']},
        'vary_phigamma': {'vals': PHI_LIN, 'label': pprint['phi']},
        'vary_betagamma': {'vals': BETA, 'label': pprint['beta']},
        'vary_thetaphi': {'vals': THETA, 'label': pprint['theta']},
    }

# %%
def read_raw_data(result_dir, exp_type='vary_thetaphi', file_prefix='none'):
    #prefix: the targeting strategy, used to filter results specific to that targeting strategy 
    res_dirs = [os.path.join(result_dir, i) for i in os.listdir(result_dir) if os.path.isdir(os.path.join(result_dir,i)) and exp_type in i]
    firstrun=res_dirs[0]
    print(res_dirs)
    respath = glob.glob('%s/%s*.json' %(firstrun, file_prefix))
    resfiles = [i.split('%s/' %firstrun)[1].replace('.json','') for i in respath]
#     print(resfiles)
    #fill in other config
    all_configs = json.load(open(config_fpath,'r'))

    params = {}
    results = {}
    #TODO: simplify this!! 
    for file in resfiles: 
    #     print(file)
        if file in all_configs[exp_type].keys():
            params[file] = all_configs[exp_type][file]
#             print(params)
            fpath = os.path.join(firstrun,'%s.json' %file)
            res = json.load(open(fpath,'r'))

            if res is not None:
                res = utils.update_dict(res, params[file])

                results[file] = res

    all_results = results.values()
    return results, all_results

# %%
def get_heatmap_data(all_results, exp_type='vary_thetaphi', cell_type='quality'):
#     results: dict of exp_name - {dict of params + list of qualities across runs}

    x = heatmap_config[exp_type]['x']
    y = heatmap_config[exp_type]['y']

    results = defaultdict(lambda: [])
    for idx, yval in enumerate(heatmap_config[exp_type]['yvals']):
        for xval in heatmap_config[exp_type]['xvals']:
            if cell_type=='discriminative_pow':
                #Fill 0 for exps that haven't finished running yet
                vals = [res[cell_type][0] for res in all_results if res[x]==xval and res[y]==yval]
                results[yval] += [np.mean(vals) if len(vals)>0 else 0] #change else back to 0
            else:
                vals = [res[cell_type] for res in all_results if res[x]==xval and res[y]==yval]
                results[yval] += [np.mean(vals) if len(vals)>0 else 0]

    data = np.array([row for row in results.values()])
    return data

# %%
cell_type='quality'
exp_type='vary_thetaphi'
results1 = read_raw_data(RES_PATH, exp_type=exp_type, file_prefix='none')
data1= get_heatmap_data(results1, exp_type=exp_type, cell_type=cell_type)
# Out:
# ['/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs']
# ['none_46', 'none_39', 'none_53', 'none_34', 'none_13', 'none_20', 'none_14', 'none_79', 'none_76', 'none_54', 'none_01', 'none_52', 'none_78', 'none_61', 'none_17', 'none_31', 'none_42', 'none_07', 'none_47', 'none_74', 'none_41', 'none_25', 'none_15', 'none_35', 'none_05', 'none_45', 'none_03', 'none_21', 'none_23', 'none_43', 'none_67', 'none_50', 'none_56', 'none_12', 'none_16', 'none_06', 'none_36', 'none_04', 'none_44', 'none_77', 'none_29', 'none_55', 'none_70', 'none_68', 'none_75', 'none_59', 'none_02', 'none_40', 'none_19', 'none_22', 'none_71', 'none_00', 'none_72', 'none_27', 'none_60', 'none_18', 'none_08', 'none_24', 'none_37', 'none_10', 'none_63', 'none_48', 'none_30', 'none_73', 'none_51', 'none_62', 'none_66', 'none_28', 'none_11', 'none_49', 'none_69', 'none_58', 'none_09', 'none_65', 'none_32', 'none_57', 'none_26', 'none_64', 'none_38', 'none_33']

# %%
results2 = read_raw_data(RES_PATH, exp_type=exp_type, file_prefix='hubs')
data2= get_heatmap_data(results2, exp_type=exp_type, cell_type=cell_type)
# Out:
# ['/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs']
# ['hubs_49', 'hubs_79', 'hubs_55', 'hubs_46', 'hubs_27', 'hubs_01', 'hubs_23', 'hubs_14', 'hubs_41', 'hubs_64', 'hubs_56', 'hubs_24', 'hubs_17', 'hubs_11', 'hubs_33', 'hubs_12', 'hubs_62', 'hubs_57', 'hubs_51', 'hubs_53', 'hubs_52', 'hubs_66', 'hubs_05', 'hubs_77', 'hubs_20', 'hubs_04', 'hubs_47', 'hubs_36', 'hubs_40', 'hubs_54', 'hubs_38', 'hubs_50', 'hubs_29', 'hubs_59', 'hubs_58', 'hubs_22', 'hubs_37', 'hubs_60', 'hubs_68', 'hubs_39', 'hubs_76', 'hubs_03', 'hubs_63', 'hubs_65', 'hubs_02', 'hubs_26', 'hubs_19', 'hubs_08', 'hubs_42', 'hubs_13', 'hubs_21', 'hubs_78', 'hubs_00', 'hubs_69', 'hubs_45', 'hubs_07', 'hubs_30', 'hubs_34', 'hubs_35', 'hubs_18', 'hubs_74', 'hubs_16', 'hubs_31', 'hubs_44', 'hubs_70', 'hubs_48', 'hubs_75', 'hubs_06', 'hubs_73', 'hubs_28', 'hubs_09', 'hubs_67', 'hubs_32', 'hubs_25', 'hubs_71', 'hubs_61', 'hubs_43', 'hubs_10', 'hubs_15', 'hubs_72']

# %%
assert data1.all()==data2.all()

# %%
# PLOT_PATH = '/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs'
utils.make_sure_dir_exists(RES_PATH, 'plots')
# Out:
# True

# %%
def compare_targeting_heatmap(exp_type='vary_thetaphi', cell_type='quality', prefixes=['none','misinformation']):
    plt.clf()
    figure, (ax1, ax2) = plt.subplots(1,2, figsize=(10, 5), facecolor='w')
    for ax, prefix in zip([ax1,ax2], prefixes):
        _, all_results = read_raw_data(RES_PATH, exp_type=exp_type, file_prefix=prefix)
        data= get_heatmap_data(all_results, exp_type=exp_type, cell_type=cell_type)
        utils.draw_heatmap(ax, data, xticks[exp_type]['vals'], PHI_LIN, xticks[exp_type]['label'], pprint['phi'], cmap, cell_type, vmax=None, vmin=None)
        ax.set_title('%s targeting' %prefix)
    figure.tight_layout()
    plt.savefig(os.path.join(RES_PATH, 'plots', '%s%s_.png' %(prefixes[0], prefixes[1])), dpi=300)
    plt.show()

# %%
compare_targeting_heatmap(exp_type='vary_thetaphi', cell_type='quality', prefixes=['none','misinformation'])
# Out:
# ['/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs']
# ['/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs']

# %%
compare_targeting_heatmap(exp_type='vary_thetaphi', cell_type='quality', prefixes=['none','partisanship'])
# Out:
# ['/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs']
# ['/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs']

# %%
compare_targeting_heatmap(exp_type='vary_thetaphi', cell_type='quality', prefixes=['none','hubs'])
# Out:
# ['/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs']
# ['/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs']

# %%
import gzip
import json 

jsonfilename = '/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs/none_42.json.gz'
with gzip.open(jsonfilename, 'r') as fin:        # 4. gzip
    json_bytes = fin.read()                      # 3. bytes (i.e. UTF-8)

json_str = json_bytes.decode('utf-8')            # 2. string (i.e. JSON)
data = json.loads(json_str)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-daf28f2542c5> in <module>
#       4 jsonfilename = '/N/slate/baotruon/marketplace/results/vary_thetaphi_1runs/none_42.json.gz'
#       5 with gzip.open(jsonfilename, 'r') as fin:        # 4. gzip
# ----> 6     json_bytes = fin.read()                      # 3. bytes (i.e. UTF-8)
#       7
#       8 json_str = json_bytes.decode('utf-8')            # 2. string (i.e. JSON)
#
# ~/miniconda3/envs/graph/lib/python3.7/gzip.py in read(self, size)
#     285             import errno
#     286             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 287         return self._buffer.read(size)
#     288
#     289     def read1(self, size=-1):
#
# ~/miniconda3/envs/graph/lib/python3.7/gzip.py in read(self, size)
#     480             buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
#     481
# --> 482             uncompress = self._decompressor.decompress(buf, size)
#     483             if self._decompressor.unconsumed_tail != b"":
#     484                 self._fp.prepend(self._decompressor.unconsumed_tail)
#
# MemoryError:

# %%
data
# Out:
# {'targeting_criterion': None,
#  'theta': 12,
#  'phi': 4,
#  'verbose': False,
#  'human_network': 'follower_network.gml',
#  'beta': 0.01,
#  'gamma': 0.01,
#  'graph_gml': '/N/slate/baotruon/marketplace/data/igraph/vary_targetgamma/network_06.gml',
#  'mode': 'igraph',
#  'quality': [0.13894876936736555],
#  'diversity': [5.518487364141627],
#  'discriminative_pow': [[0.8312154435386241, 0.0]],
#  'memes': [[{'id': 1,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.20816195759251166,
#     'fitness': 0.20816195759251166,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 59638,
#     'share_th': 54014},
#    {'id': 2,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.09885657694626104,
#     'fitness': 0.09885657694626104,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 35646,
#     'share_th': 33225},
#    {'id': 3,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.

#     'human_shares': 4,
#     'bot_shares': 0,
#     'qual_th': 47488,
#     'share_th': 82968},
#    {'id': 84,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.16915877440490668,
#     'fitness': 0.16915877440490668,
#     'human_shares': 6,
#     'bot_shares': 0,
#     'qual_th': 52421,
#     'share_th': 84362},
#    {'id': 85,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.12658186371733693,
#     'fitness': 0.12658186371733693,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 42818,
#     'share_th': 39634},
#    {'id': 86,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.17297360598131406,
#     'fitness': 0.17297360598131406,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 53220,
#     'share_th': 48666},
#    {'id': 87,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.3111775549807305,
#     'fitness': 0.3111775549807305,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 72883,
#     'share_th': 64644},
#    {'id': 88,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.3777849777133847,
#     'fitness': 0.3777849777133847,
#     'human_shares': 11,
#     'bot_shares': 0,
#     'qual_th': 78242,
#     'share_th': 85302},
#    {'id': 89,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.133917441116991,
#     'fitness': 0.133917441116991,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 44635,
#     'share_th': 41238},
#    {'id': 90,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.002777339913474397,
#     'fitness': 0.002777339913474397,
#     'human_shares': 4,
#     'bot_shares': 0,
#     'qual_th': 2102,
#     'share_th': 82832},
#    {'id': 91,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.28170605137655247,
#     'fitness': 0.28170605137655247,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 69834,
#     'share_th': 62249},
#    {'id': 92,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.2563342682613713,
#     'fitness': 0.2563342682613713,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 66634,
#     'share_th': 59741},
#    {'id': 93,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.1979488531683612,
#     'fitness': 0.1979488531683612,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 57908,
#     'share_th': 52576},
#    {'id': 94,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.1968067268559538,
#     'fitness': 0.1968067268559538,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 57680,
#     'share_th': 52388},
#    {'id': 95,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.03789788107207348,
#     'fitness': 0.03789788107207348,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 15912,
#     'share_th': 14765},
#    {'id': 96,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.08620706502263786,
#     'fitness': 0.08620706502263786,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 31990,
#     'share_th': 29879},
#    {'id': 97,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.01576806761998162,
#     'fitness': 0.01576806761998162,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 7440,
#     'share_th': 6550},
#    {'id': 98,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.009496440082857327,
#     'fitness': 0.009496440082857327,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 4900,
#     'share_th': 4051},
#    {'id': 99,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.20656204900659159,
#     'fitness': 0.20656204900659159,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 59349,
#     'share_th': 77593},
#    {'id': 100,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.19312696887110892,
#     'fitness': 0.19312696887110892,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 57082,
#     'share_th': 51904},
#    {'id': 101,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.09011169190169677,
#     'fitness': 0.09011169190169677,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 33154,
#     'share_th': 30949},
#    {'id': 102,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.12150774317066027,
#     'fitness': 0.12150774317066027,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 41556,
#     'share_th': 38504},
#    {'id': 103,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.07674885523828157,
#     'fitness': 0.07674885523828157,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 29095,
#     'share_th': 75033},
#    {'id': 104,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.08276985285679062,
#     'fitness': 0.08276985285679062,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 30953,
#     'share_th': 28948},
#    {'id': 105,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.21125348889745077,
#     'fitness': 0.21125348889745077,
#     'human_shares': 11,
#     'bot_shares': 0,
#     'qual_th': 60187,
#     'share_th': 85283},
#    {'id': 106,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.29859649720211934,
#     'fitness': 0.29859649720211934,
#     'human_shares': 3,
#     'bot_shares': 0,
#     'qual_th': 71660,
#     'share_th': 82046},
#    {'id': 107,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.4538663720406444,
#     'fitness': 0.4538663720406444,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 82007,
#     'share_th': 71378},
#    {'id': 108,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.04587198301095197,
#     'fitness': 0.04587198301095197,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 18827,
#     'share_th': 17573},
#    {'id': 109,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.1495419660928694,
#     'fitness': 0.1495419660928694,
#     'human_shares': 11,
#     'bot_shares': 0,
#     'qual_th': 48233,
#     'share_th': 85281},
#    {'id': 110,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.15106503162001528,
#     'fitness': 0.15106503162001528,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th':

#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.4710969369286899,
#     'fitness': 0.4710969369286899,
#     'human_shares': 26,
#     'bot_shares': 0,
#     'qual_th': 82586,
#     'share_th': 85765},
#    {'id': 166,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.027761230315875407,
#     'fitness': 0.027761230315875407,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 12134,
#     'share_th': 11135},
#    {'id': 167,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.062218862212659154,
#     'fitness': 0.062218862212659154,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 24419,
#     'share_th': 22869},
#    {'id': 168,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.04246548725371346,
#     'fitness': 0.04246548725371346,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 17648,
#     'share_th': 16435},
#    {'id': 169,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.02022471589793029,
#     'fitness': 0.02022471589793029,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 9158,
#     'share_th': 8246},
#    {'id': 170,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.2124863617334375,
#     'fitness': 0.2124863617334375,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 60377,
#     'share_th': 54632},
#    {'id': 171,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.13857974752586044,
#     'fitness': 0.13857974752586044,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 45747,
#     'share_th': 76274},
#    {'id': 172,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.14403424441028256,
#     'fitness': 0.14403424441028256,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 46996,
#     'share_th': 76389},
#    {'id': 173,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.022335010843319125,
#     'fitness': 0.022335010843319125,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 9972,
#     'share_th': 9035},
#    {'id': 174,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.0019367873256619372,
#     'fitness': 0.0019367873256619372,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 1735,
#     'share_th': 905},
#    {'id': 175,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.09349827947339395,
#     'fitness': 0.09349827947339395,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 34138,
#     'share_th': 31849},
#    {'id': 176,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.1769987856953208,
#     'fitness': 0.1769987856953208,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 54016,
#     'share_th': 49321},
#    {'id': 177,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.3662313234678647,
#     'fitness': 0.3662313234678647,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 77421,
#     'share_th': 68045},
#    {'id': 178,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.38680481402207467,
#     'fitness': 0.38680481402207467,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 78839,
#     'share_th': 69103},
#    {'id': 179,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.053486580205067136,
#     'fitness': 0.053486580205067136,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 21518,
#     'share_th': 20125},
#    {'id': 180,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.10338401440920308,
#     'fitness': 0.10338401440920308,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 36882,
#     'share_th': 34326},
#    {'id': 181,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.024212804973333002,
#     'fitness': 0.024212804973333002,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 10720,
#     'share_th': 9763},
#    {'id': 182,
#     'is_by_bot': 1.0,
#     'phi': 4,
#     'quality': 0,
#     'fitness': 0.6029694761296804,
#     'human_shares': 32,
#     'bot_shares': 24,
#     'qual_th': 1,
#     'share_th': 85814},
#    {'id': 183,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.07632916805888645,
#     'fitness': 0.07632916805888645,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 28954,
#     'share_th': 75027},
#    {'id': 184,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.14115801354691182,
#     'fitness': 0.14115801354691182,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 46345,
#     'share_th': 42725},
#    {'id': 185,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.13068772348048063,
#     'fitness': 0.13068772348048063,
#     'human_shares': 9,
#     'bot_shares': 0,
#     'qual_th': 43857,
#     'share_th': 85079},
#    {'id': 186,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.1256926428208358,
#     'fitness': 0.1256926428208358,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 42621,
#     'share_th': 39460},
#    {'id': 187,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.0019581415859533102,
#     'fitness': 0.0019581415859533102,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 1744,
#     'share_th': 914},
#    {'id': 188,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.1351082576908208,
#     'fitness': 0.1351082576908208,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 44921,
#     'share_th': 41488},
#    {'id': 189,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.42920247433112524,
#     'fitness': 0.42920247433112524,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 81016,
#     'share_th': 70651},
#    {'id': 190,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.03395630027369445,
#     'fitness': 0.03395630027369445,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 14495,
#     'share_th': 74370},
#    {'id': 191,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.11354967491443169,
#     'fitness': 0.11354967491443169,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 39511,
#     'share_th': 36680},
#    {'id': 192,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.18932508175530327,
#     'fitness': 0.18932508175530327,
#     'human_shares': 4,
#     'bot_shares': 0,
#     'qual_th': 56359,
#     'share_th': 83075},
#    {'id': 193,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.035515217950075284,
#     'fitness': 0.035515217950075284,
#     'human_shares': 3,
#     'bot_shares': 0,
#     'qual_th': 15047,
#     'share_th': 80816},
#    {'id': 194,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.11902102332693287,
#     'fitness': 0.11902102332693287,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 40912,
#     'share_th': 75907},
#    {'id': 195,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.1698397050185817,
#     'fitness': 0.1698397050185817,
#     'human_shares': 5,
#     'bot_shares': 0,
#     'qual_th': 52585,
#     'share_th': 83854},
#    {'id': 196,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.22993324505492407,
#     'fitness': 0.22993324505492407,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 62995,
#     'share_th': 56798},
#    {'id': 197,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.11403801151758008,
#     'fitness': 0.11403801151758008,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 39646,
#     'share_th': 75796},
#    {'id': 198,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.03340924533080303,
#     'fitness': 0.03340924533080303,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 14278,
#     'share_th': 13210},
#    {'id': 199,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.05536313478104271,
#     'fitness': 0.05536313478104271,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 22158,
#     'share_th': 74665},
#    {'id': 200,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.047890432211325495,
#     'fitness': 0.047890432211325495,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 19519,
#     'share_th': 18235},
#    {'id': 201,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.2650246620478014,
#     'fitness': 0.2650246620478014,
#     'human_shares': 3,
#     'bot_shares': 0,
#     'qual_th': 67774,
#     'share_th': 81876},
#    {'id': 202,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.016183297038801947,
#     'fitness': 0.016183297038801947,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 7597,
#     'share_th': 6706},
#    {'id': 203,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.047439716742201266,
#     'fitness': 0.047439716742201266,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 19370,
#     'share_th': 18094},
#    {'id': 204,
#     'is_by_bot': 1.0,
#     'phi': 4,
#     'quality': 0,
#     'fitness': 0.948796408292977,
#     'human_shares': 5666,
#     'bot_shares': 12,
#     'qual_th': 2,
#     'share_th': 86033},
#    {'id': 205,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.039621180516658305,
#     'fitness': 0.039621180516658305,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 16589,
#     'share_th': 15417},
#    {'id': 206,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.573566485362969,
#     'fitness': 0.573566485362969,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 84823,
#     'share_th': 73315},
#    {'id': 207,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.27173745326542087,
#     'fitness': 0.27173745326542087,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 68639,
#     'share_th': 61314},
#    {'id': 208,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.05751881094808353,
#     'fitness': 0.05751881094808353,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 22863,
#     'share_th': 74702},
#    {'id': 209,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.21223918510697337,
#     'fitness': 0.21223918510697337,
#     'human_shares': 3,
#     'bot_shares': 0,
#     'qual_th': 60335,
#     'share_th': 81600},
#    {'id': 210,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.5047724677504821,
#     'fitness': 0.5047724677504821,
#     'human_shares': 4,
#     'bot_shares': 0,
#     'qual_th': 83534,
#     'share_th': 83674},
#    {'id': 211,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.29119127457808447,
#     'fitness': 0.29119127457808447,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 70852,
#     'share_th': 78882},
#    {'id': 212,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.37740926314965206,
#     'fitness': 0.37740926314965206,
#     'human_shares': 3,
#     'bot_shares': 0,
#     'qual_th': 78213,
#     'share_th': 82357},
#    {'id': 213,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.10548280598530368,
#     'fitness': 0.10548280598530368,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 37439,
#     'share_th': 34821},
#    {'id': 214,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.18330394669313377,
#     'fitness': 0.18330394669313377,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 55245,
#     'share_th': 50371},
#    {'id': 215,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.1799618060751743,
#     'fitness': 0.1799618060751743,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 54612,
#     'share_th': 49837},
#    {'id': 216,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.0036768688532464733,
#     'fitness': 0.0036768688532464733,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 2520,
#     'share_th': 1686},
#    {'id': 217,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.22182422238164012,
#     'fitness': 0.22182422238164012,
#     'human_shares': 6,
#     'bot_shares': 0,
#     'qual_th': 61782,
#     'share_th': 84402},
#    {'id': 218,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.014003299670017122,
#     'fitness': 0.014003299670017122,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 6788,
#     'share_th': 5913},
#    {'id': 219,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.5387968291145484,
#     'fitness': 0.5387968291145484,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 84253,
#     'share_th': 80550},
#    {'id': 220,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.06778138193511529,
#     'fitness': 0.06778138193511529,
#     'human_shares': 2,
#     'bot_shares': 0,
#     'qual_th': 26181,
#     'share_th': 74883},
#    {'id': 221,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.056180265841645816,
#     'fitness': 0.056180265841645816,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 22415,
#     'share_th': 20977},
#    {'id': 222,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.25796643934600993,
#     'fitness': 0.25796643934600993,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 66835,
#     'share_th': 59895},
#    {'id': 223,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.13894215447979164,
#     'fitness': 0.13894215447979164,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 45826,
#     'share_th': 42284},
#    {'id': 224,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.006997728192486785,
#     'fitness': 0.006997728192486785,
#     'human_shares': 1,
#     'bot_shares': 0,
#     'qual_th': 3886,
#     'share_th': 3045},
#    {'id': 225,
#     'is_by_bot': 0.0,
#     'phi': 4,
#     'quality': 0.022935039608301455,
# ...
#     85828,
#     85759,
#     75709,
#     84831],
#    '133531': [86012,
#     86007,
#     85977,
#     85933,
#     85404,
#     85760,
#     85654,
#     85584,
#     85508,
#     69520,
#     84095,
#     85295,
#     75709,
#     84469,
#     85200],
#    '67998': [85982,
#     85857,
#     85800,
#     85550,
#     75709,
#     84200,
#     84946,
#     84932,
#     84690,
#     84653,
#     84598,
#     84542,
#     84118,
#     83655,
#     83995],
#    '2467': [86002,
#     79982,
#     85887,
#     85642,
#     85642,
#     75709,
#     75709,
#     79982,
#     74969,
#     85218,
#     85135,
#     83397,
#     85013,
#     85013,
#     85013],
#    '133541': [79982,
#     85988,
#     85569,
#     69520,
#     85481,
#     85358,
#     75709,
#     84095,
#     79982,
#     85122,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709],
#    '100774': [86028,
#     86003,
#     69520,
#     85694,
#     85971,
#     85800,
#     85911,
#     85862,
#     85753,
#     69520,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856],
#    '100778': [86011,
#     85988,
#     85910,
#     85723,
#     85688,
#     79982,
#     85623,
#     85586,
#     79982,
#     85415,
#     79982,
#     85326,
#     84781,
#     69520,
#     85205],
#    '2474': [75709,
#     85092,
#     85908,
#     75709,
#     85896,
#     85854,
#     85851,
#     85729,
#     85801,
#     69520,
#     85768,
#     83995,
#     85729,
#     79982,
#     85703],
#    '68018': [85705,
#     85642,
#     85503,
#     82524,
#     85338,
#     69520,
#     84396,
#     84692,
#     84609,
#     84401,
#     75709,
#     83863,
#     75709,
#     83425,
#     69520],
#    '100791': [85964,
#     86003,
#     85778,
#     85869,
#     85919,
#     85708,
#     85800,
#     85708,
#     85656,
#     69520,
#     69520,
#     69520,
#     85096,
#     84810,
#     69520],
#    '100794': [86035,
#     86003,
#     69520,
#     69520,
#     85893,
#     74969,
#     85860,
#     85753,
#     69520,
#     85708,
#     85800,
#     85771,
#     85753,
#     69520,
#     69520],
#    '100797': [86009,
#     85988,
#     85966,
#     85959,
#     85902,
#     85657,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835],
#    '133566': [82678,
#     85831,
#     69520,
#     85092,
#     85654,
#     85596,
#     85586,
#     85530,
#     85520,
#     69520,
#     84781,
#     85276,
#     85227,
#     85092,
#     85092],
#    '68031': [86006,
#     85984,
#     85971,
#     69520,
#     85862,
#     85843,
#     69520,
#     82678,
#     85553,
#     85740,
#     85727,
#     85724,
#     85716,
#     85679,
#     69520],
#    '100801': [86028,
#     69520,
#     86024,
#     69520,
#     86016,
#     85964,
#     86003,
#     85975,
#     85972,
#     69520,
#     85931,
#     85897,
#     85880,
#     69520,
#     85694],
#    '35266': [86017,
#     85092,
#     74969,
#     85749,
#     85586,
#     78472,
#     75709,
#     85122,
#     75709,
#     84941,
#     84914,
#     69520,
#     75709,
#     75709,
#     75709],
#    '133569': [86011,
#     69520,
#     69520,
#     85586,
#     74969,
#     75709,
#     85586,
#     85396,
#     79982,
#     79982,
#     69520,
#     75709,
#     73298,
#     84756,
#     84719],
#    '133573': [75709,
#     85993,
#     85982,
#     85978,
#     85920,
#     85728,
#     85724,
#     85625,
#     69520,
#     75709,
#     69520,
#     85377,
#     69520,
#     85145,
#     85096],
#    '68039': [86007,
#     85890,
#     74969,
#     85790,
#     85782,
#     85729,
#     85700,
#     85642,
#     85669,
#     85654,
#     85607,
#     85583,
#     75709,
#     75709,
#     79982],
#    '133578': [85694,
#     85470,
#     85920,
#     85919,
#     85911,
#     85881,
#     85800,
#     69520,
#     85553,
#     75709,
#     69520,
#     79982,
#     85178,
#     85251,
#     85189],
#    '133580': [86007,
#     85856,
#     85404,
#     85790,
#     83995,
#     85728,
#     83397,
#     85099,
#     85524,
#     79982,
#     84656,
#     85422,
#     82446,
#     85381,
#     79982],
#    '35277': [69520,
#     85978,
#     85779,
#     85893,
#     85881,
#     82856,
#     85860,
#     85794,
#     85694,
#     75709,
#     85756,
#     85553,
#     85708,
#     85679,
#     85635],
#    '2510': [85933,
#     85404,
#     85099,
#     85569,
#     75709,
#     85373,
#     85014,
#     79982,
#     75709,
#     80700,
#     84535,
#     83995,
#     69520,
#     84337,
#     69520],
#    '68046': [84522,
#     83397,
#     83397,
#     83397,
#     83397,
#     83397,
#     83397,
#     83397,
#     83397,
#     83397,
#     83397,
#     83397,
#     83397,
#     84427,
#     84405],
#    '133586': [79982,
#     85654,
#     85948,
#     74969,
#     75709,
#     85768,
#     79982,
#     79982,
#     85654,
#     85636,
#     84897,
#     85586,
#     75709,
#     78472,
#     85534],
#    '68051': [85988,
#     85856,
#     79982,
#     85661,
#     85654,
#     85602,
#     77747,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709],
#    '2528': [85964,
#     85993,
#     85778,
#     85982,
#     85800,
#     85950,
#     85869,
#     85920,
#     69520,
#     85876,
#     85753,
#     69520,
#     85828,
#     85828,
#     85828],
#    '68065': [85741,
#     79481,
#     79982,
#     79982,
#     74969,
#     85460,
#     85380,
#     85334,
#     75709,
#     85248,
#     85197,
#     79982,
#     79982,
#     85092,
#     85092],
#    '100836': [77211,
#     77211,
#     77211,
#     77211,
#     77211,
#     77211,
#     77211,
#     77211,
#     77211,
#     77211,
#     77211,
#     77211,
#     76194,
#     76194,
#     76194],
#    '2536': [86035,
#     86024,
#     86006,
#     86000,
#     85204,
#     85994,
#     85993,
#     85778,
#     69520,
#     69520,
#     85761,
#     85694,
#     85950,
#     85946,
#     85939],
#    '133609': [85099,
#     85795,
#     84261,
#     69520,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969],
#    '133615': [86024,
#     85993,
#     85984,
#     85982,
#     85800,
#     85943,
#     85920,
#     85911,
#     69520,
#     69520,
#     85753,
#     85708,
#     85794,
#     85694,
#     85780],
#    '2544': [86007,
#     83397,
#     85092,
#     85623,
#     82524,
#     85120,
#     85288,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969,
#     74969],
#    '2545': [85652,
#     86028,
#     86027,
#     69520,
#     85964,
#     86000,
#     85994,
#     85993,
#     85980,
#     85982,
#     85944,
#     85932,
#     85922,
#     85920,
#     85869],
#    '35323': [86032,
#     86026,
#     85654,
#     85990,
#     85973,
#     79481,
#     85654,
#     85092,
#     85934,
#     85910,
#     79982,
#     74969,
#     75709,
#     84480,
#     85835],
#    '133629': [86028,
#     86003,
#     69520,
#     85984,
#     69520,
#     85906,
#     85872,
#     85753,
#     85753,
#     69520,
#     85708,
#     69520,
#     85721,
#     85804,
#     85794],
#    '100864': [85947,
#     85751,
#     84863,
#     85832,
#     85795,
#     85700,
#     85692,
#     69520,
#     69520,
#     85605,
#     85551,
#     85527,
#     85519,
#     74969,
#     74969],
#    '35329': [74969,
#     85790,
#     85768,
#     85015,
#     85642,
#     79982,
#     75709,
#     79481,
#     85654,
#     85641,
#     85602,
#     85586,
#     84201,
#     79982,
#     85282],
#    '100866': [79982,
#     85878,
#     75709,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856],
#    '35335': [86011,
#     85812,
#     85782,
#     85449,
#     85686,
#     85623,
#     85569,
#     85461,
#     85507,
#     85248,
#     85437,
#     85419,
#     79982,
#     85407,
#     85372],
#    '2568': [69520,
#     85862,
#     85731,
#     85652,
#     85599,
#     85480,
#     85384,
#     85373,
#     85373,
#     85373,
#     85373,
#     85373,
#     85373,
#     85373,
#     85373],
#    '68105': [69520,
#     82524,
#     85978,
#     85753,
#     85716,
#     75709,
#     85616,
#     85697,
#     85679,
#     85599,
#     85568,
#     75709,
#     85352,
#     85387,
#     83631],
#    '2569': [85654,
#     79982,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828,
#     85741],
#    '133645': [83397,
#     85642,
#     84095,
#     84095,
#     84095,
#     84095,
#     84095,
#     84095,
#     84095,
#     84095,
#     84095,
#     84095,
#     84095,
#     84095,
#     84914],
#    '100881': [86020,
#     86013,
#     85778,
#     85982,
#     79481,
#     82856,
#     85964,
#     85955,
#     75709,
#     85869,
#     85924,
#     85903,
#     85881,
#     82856,
#     85708],
#    '2579': [85993,
#     85877,
#     85872,
#     85858,
#     85753,
#     85804,
#     85794,
#     85740,
#     75709,
#     85755,
#     85553,
#     75709,
#     69520,
#     85652,
#     69520],
#    '133654': [69520,
#     85993,
#     85982,
#     85978,
#     85924,
#     85922,
#     85920,
#     69520,
#     82856,
#     85865,
#     85843,
#     85694,
#     85755,
#     85616,
#     69520],
#    '35351': [85982,
#     85881,
#     85694,
#     85753,
#     69520,
#     85804,
#     85794,
#     85616,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709],
#    '133658': [69520,
#     85984,
#     85952,
#     85909,
#     85872,
#     85753,
#     85708,
#     83995,
#     85740,
#     85665,
#     85616,
#     69520,
#     85652,
#     85640,
#     85568],
#    '2590': [74969,
#     69520,
#     79481,
#     79481,
#     79481,
#     79481,
#     79481,
#     79481,
#     79481,
#     79481,
#     79481,
#     79481,
#     79481,
#     79481,
#     85368],
#    '133662': [85652,
#     86028,
#     85993,
#     85950,
#     85911,
#     85885,
#     85867,
#     85862,
#     69520,
#     69520,
#     85721,
#     85804,
#     85800,
#     85694,
#     69520],
#    '35362': [85987,
#     85983,
#     85654,
#     85802,
#     75709,
#     85798,
#     83397,
#     85654,
#     85650,
#     79982,
#     85569,
#     85586,
#     79982,
#     85461,
#     85512],
#    '68132': [85988,
#     85948,
#     85900,
#     85404,
#     85751,
#     85700,
#     85654,
#     85623,
#     69520,
#     85586,
#     85584,
#     78472,
#     85512,
#     85438,
#     85407],
#    '2597': [85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85820,
#     85749,
#     85728],
#    '68134': [69520,
#     85993,
#     85778,
#     85971,
#     85869,
#     85911,
#     85893,
#     85876,
#     85864,
#     85862,
#     85860,
#     69520,
#     85804,
#     85694,
#     85778],
#    '35368': [69520,
#     85950,
#     85800,
#     69520,
#     85599,
#     69520,
#     85087,
#     69520,
#     72514,
#     69520,
#     84643,
#     84530,
#     69520,
#     84425,
#     69520],
#    '2609': [86028,
#     86003,
#     85982,
#     85694,
#     69520,
#     85862,
#     85753,
#     69520,
#     85830,
#     85721,
#     85804,
#     85794,
#     85740,
#     75709,
#     85553],
#    '35377': [86028,
#     85993,
#     85778,
#     85982,
#     85950,
#     85939,
#     85937,
#     85869,
#     85909,
#     85877,
#     85867,
#     85864,
#     85804,
#     85800,
#     69520],
#    '2611': [85708,
#     85794,
#     85753,
#     82678,
#     85605,
#     69520,
#     85599,
#     85402,
#     85238,
#     84997,
#     84994,
#     84938,
#     75709,
#     84872,
#     84242],
#    '68148': [86028,
#     85978,
#     85694,
#     85950,
#     85893,
#     85860,
#     69520,
#     85553,
#     69520,
#     69520,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092],
#    '2613': [85993,
#     85352,
#     69520,
#     85274,
#     84749,
#     84530,
#     77137,
#     84425,
#     83841,
#     75709,
#     69520,
#     83413,
#     83309,
#     82205,
#     82928],
#    '35378': [79982,
#     85907,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     85835,
#     82856],
#    '35384': [86028,
#     86016,
#     69520,
#     85872,
#     85753,
#     85800,
#     69520,
#     85731,
#     85727,
#     85726,
#     85599,
#     69520,
#     69520,
#     85498,
#     69520],
#    '2617': [85988,
#     74969,
#     85757,
#     79982,
#     85736,
#     85700,
#     79982,
#     85569,
#     85586,
#     75709,
#     85460,
#     85531,
#     85530,
#     85520,
#     85508],
#    '133693': [86008,
#     78472,
#     78472,
#     75709,
#     85857,
#     85810,
#     85798,
#     85791,
#     85785,
#     85642,
#     85650,
#     75709,
#     83152,
#     75709,
#     75709],
#    '35397': [85092,
#     82524,
#     85099,
#     85768,
#     79982,
#     85749,
#     85642,
#     85569,
#     85479,
#     85437,
#     85431,
#     85374,
#     69520,
#     85335,
#     85187],
#    '68169': [85993,
#     85778,
#     85982,
#     85980,
#     85869,
#     85920,
#     85919,
#     69520,
#     85905,
#     85708,
#     85800,
#     85796,
#     85794,
#     85755,
#     85731],
#    '35406': [86019,
#     86006,
#     85984,
#     85694,
#     85950,
#     85939,
#     85748,
#     85931,
#     85916,
#     69520,
#     85891,
#     85862,
#     69520,
#     85721,
#     85721],
#    '35408': [85778,
#     85869,
#     85923,
#     85922,
#     69520,
#     85911,
#     85895,
#     85870,
#     83995,
#     85665,
#     85724,
#     85716,
#     69520,
#     85608,
#     69520],
#    '68180': [86026,
#     85918,
#     85990,
#     79481,
#     85890,
#     85790,
#     85851,
#     85404,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828,
#     85828],
#    '2645': [85675,
#     69520,
#     84095,
#     85005,
#     75709,
#     75709,
#     79982,
#     75709,
#     84755,
#     84748,
#     84736,
#     84640,
#     83545,
#     84391,
#     84382],
#    '133717': [74969,
#     85854,
#     85819,
#     85751,
#     85749,
#     85728,
#     75709,
#     75709,
#     85623,
#     85573,
#     75709,
#     85449,
#     84721,
#     85428,
#     69520],
#    '133719': [86007,
#     79982,
#     85948,
#     74969,
#     85856,
#     85790,
#     69520,
#     85768,
#     75709,
#     85749,
#     85728,
#     85700,
#     85661,
#     85646,
#     85586],
#    '2652': [85652,
#     69520,
#     85993,
#     85982,
#     85968,
#     85800,
#     85957,
#     85939,
#     85922,
#     85920,
#     85911,
#     85898,
#     85893,
#     85881,
#     85708],
#    '133724': [85950,
#     85864,
#     85753,
#     85831,
#     75709,
#     85694,
#     69520,
#     75709,
#     85553,
#     69520,
#     69520,
#     75709,
#     75709,
#     75709,
#     75709],
#    '2656': [75709,
#     85751,
#     85642,
#     85661,
#     85642,
#     69520,
#     85569,
#     85431,
#     84095,
#     85207,
#     77747,
#     85191,
#     85092,
#     85092,
#     85092],
#    '100963': [86028,
#     85964,
#     85993,
#     85893,
#     85877,
#     85872,
#     85860,
#     69520,
#     85804,
#     85800,
#     85740,
#     85724,
#     85721,
#     69520,
#     69520],
#    '133738': [86020,
#     85993,
#     85778,
#     85982,
#     85869,
#     85893,
#     85860,
#     69520,
#     85830,
#     85804,
#     85800,
#     69520,
#     69520,
#     85568,
#     85599],
#    '35436': [78472,
#     85857,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85791],
#    '68205': [85652,
#     86020,
#     69520,
#     85150,
#     85652,
#     85993,
#     85980,
#     85778,
#     69520,
#     69520,
#     85981,
#     85980,
#     85971,
#     85961,
#     85955],
#    '100972': [85978,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     82856,
#     75709,
#     69520],
#    '100976': [85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85478,
#     84608,
#     84454],
#    '35440': [85987,
#     85983,
#     85851,
#     85404,
#     85790,
#     85768,
#     85729,
#     85700,
#     85642,
#     85669,
#     85661,
#     85654,
#     77747,
#     75709,
#     79982],
#    '68208': [85652,
#     86028,
#     85778,
#     85831,
#     69520,
#     85869,
#     85753,
#     85721,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092],
#    '100980': [86024,
#     85982,
#     85979,
#     85978,
#     85914,
#     85869,
#     69520,
#     85549,
#     85178,
#     85226,
#     85145,
#     69520,
#     84095,
#     84095,
#     84095],
#    '100986': [86028,
#     85993,
#     85982,
#     85932,
#     85911,
#     85708,
#     85794,
#     85755,
#     85553,
#     69520,
#     85652,
#     69520,
#     85589,
#     85541,
#     85511],
#    '133759': [85790,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85092,
#     85768,
#     85586],
#    '35458': [85936,
#     83214,
#     84396,
#     85184,
#     85032,
#     84944,
#     84775,
#     84684,
#     84396,
#     84405,
#     83676,
#     79982,
#     82068,
#     83676,
#     83676],
#    '68230': [85933,
#     85631,
#     79982,
#     85373,
#     84944,
#     84715,
#     84635,
#     84114,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709],
#    '133767': [86013,
#     85964,
#     86006,
#     69520,
#     85694,
#     85862,
#     85800,
#     85755,
#     85753,
#     85724,
#     85716,
#     85616,
#     85656,
#     79982,
#     85553],
#    '101000': [85950,
#     85924,
#     85920,
#     85893,
#     82856,
#     85708,
#     85860,
#     85800,
#     69520,
#     85726,
#     69520,
#     85643,
#     85599,
#     85518,
#     85470],
#    '68232': [85800,
#     75709,
#     69520,
#     84938,
#     72514,
#     84756,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709,
#     75709],
#    ...}]}
